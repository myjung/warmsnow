# %%
import csv
import json
import xml
from pprint import pprint as pp

# %%
def read_csv(file):
    with open(file, encoding="utf-8") as f:
        first_8_letter = f.read(8)
        if first_8_letter.startswith('\ufeff'):
            f.seek(3)
        else:
            f.seek(0)
        reader = csv.DictReader(f)
        return list(reader)

# %%
def make_xliff(data:list[dict], src_lang, trg_lang):
    #TODO: implement this function
    pass

# %%
dict_data = read_csv("1230.csv")

# %%
pp(dict_data)
# Out:
# [{'CHT': '返回', 'KOR': '뒤로 가기', 'Name': 'Common_Return'},
#  {'CHT': '封印', 'KOR': '봉인', 'Name': 'Common_Seal'},
#  {'CHT': '解除封印', 'KOR': '봉인 해제', 'Name': 'Common_Unseal'},
#  {'CHT': '重置', 'KOR': '초기화', 'Name': 'Common_Reset'},
#  {'CHT': '聖物圖鑒', 'KOR': '성물 도감', 'Name': 'UI_Potiondex_Name'},
#  {'CHT': '神兵圖鑒', 'KOR': '신병 도감', 'Name': 'UI_HolySworddex_Name'},
#  {'CHT': '生成一個自選聖物', 'KOR': '선택한 성물 생성', 'Name': 'UI_Potiondex_Generate'},
#  {'CHT': '瘋狂聚寶盆現在會在遊戲中亂入，擊敗其會獲得大量獎勵',
#   'KOR': '광란의 보물 상자가 무작위로 등장하며, 이를 처치하면 대량의 보상을 획득할 수 있습니다.',
#   'Name': 'UI_RedSoul_Desc_0'},
#  {'CHT': '瘋狂寶物庫現在會加入進隨機房間中，當玩家進入瘋狂寶物庫，將會遭遇巨型瘋狂聚寶盆',
#   'KOR': '광란의 보물고가 무작위로 나타나며, 보물고에 들어가면, 거대한 광란의 보물 상자와 조우합니다.',
#   'Name': 'UI_RedSoul_Desc_1'},
#  {'CHT': '血媚娘現在會出現在中轉站，收取紅魂出售強力裝備給玩家',
#   'KOR': '피의 여인이 경유지에 나타나 붉은 혼으로 살 수 있는 강력한 장비를 판매합니다.',
#   'Name': 'UI_RedSoul_Desc_2'},
#  {'CHT': '解放基地塚中的劍塚，使玩家可以在劍塚中自選神兵，但在自選模式下，玩家通關時，將無法提升難度。',
#   'KOR': '기지묘 안의 검총을 해금하면 검총에서 신병을 자유롭게 고를 수 있지만, 선택 모드에서 해당 난이도를 정복해도 난이도를 높일 '
#          '수 없습니다.',
#   'Name': 'UI_RedSoul_Desc_3'},
#  {'CHT': '解放基地塚中的寶庫，使玩家可以在寶庫中自選聖物，但在自選模式下，玩家通關時，將無法提升難度。',
#   'KOR': '기지묘 안의 보고를 해금하면 보고에서 성물을 고를 수 있지만, 선택 모드에서 해당 난이도를 정복해도 난이도를 높일 수 '
#          '없습니다.',
#   'Name': 'UI_RedSoul_Desc_4'},
#  {'CHT': '使玩家可以花費紅魂封印神兵，將其移出掉落列表。',
#   'KOR': '붉은 혼을 소모하여 신병의 봉인을 해제하고 드랍 목록에서 제외합니다.',
#   'Name': 'UI_RedSoul_Desc_5'},
#  {'CHT': '使玩家可以花費紅魂封印聖物，將其移出掉落列表。',
#   'KOR': '붉은 혼을 소모하여 성물의 봉인을 해제하고 드랍 목록에서 제외합니다.',
#   'Name': 'UI_RedSoul_Desc_6'},
#  {'CHT': '小偷將會允許你最多拿走2個獎勵。',
#   'KOR': '도둑이 보상 2개를 추가로 줍니다.',
#   'Name': 'UI_RedSoul_Desc_7'},
#  {'CHT': '靈魂鐵匠將允許你使用紅魂來強化和洗練神兵。',
#   'KOR': '영혼 대장장이가 붉은 혼을 사용하여 신병을 강화하고 정제합니다.',
#   'Name': 'UI_RedSoul_Desc_8'},
#  {'CHT': '解鎖新宗派佛像[神行迷蹤天尊]',
#   'KOR': '새로운 종파 불상 해금: 신행미종천존',
#   'Name': 'UI_RedSoul_Desc_9'},
#  {'CHT': '可以消耗紅魂來鎖定詞條',
#   'KOR': '붉은 혼을 사용해 부착 효과를 잠글 수 있습니다.',
#   'Name': 'UI_RedSoul_Desc_10'},
#  {'CHT': '瘋狂至寶', 'KOR': '광란의 보물', 'Name': 'UI_RedSoul_Name_0'},
#  {'CHT': '瘋狂寶物庫', 'KOR': '광란의 보물고', 'Name': 'UI_RedSoul_Name_1'},
#  {'CHT': '血之契', 'KOR': '피의 맹약', 'Name': 'UI_RedSoul_Name_2'},
#  {'CHT': '石門解封：劍塚', 'KOR': '석문해방: 검총', 'Name': 'UI_RedSoul_Name_3'},
#  {'CHT': '石門解封：寶庫', 'KOR': '석문해방: 보고', 'Name': 'UI_RedSoul_Name_4'},
#  {'CHT': '神兵封印', 'KOR': '신병봉인', 'Name': 'UI_RedSoul_Name_5'},
#  {'CHT': '聖物封印', 'KOR': '성물봉인', 'Name': 'UI_RedSoul_Name_6'},
#  {'CHT': '盜亦成雙', 'KOR': '도역성쌍', 'Name': 'UI_RedSoul_Name_7'},
#  {'CHT': '血色鑄造', 'KOR': '혈색주조', 'Name': 'UI_RedSoul_Name_8'},
#  {'CHT': '神行迷蹤天尊的記憶', 'KOR': '신행미종천존의 기억', 'Name': 'UI_RedSoul_Name_9'},
#  {'CHT': '血色洗練', 'KOR': '혈색제련', 'Name': 'UI_RedSoul_Name_10'},
#  {'CHT': '赤魂奇珍', 'KOR': '적혼기진', 'Name': 'UI_RedSoul_Title'},
#  {'CHT': '切換已解鎖的商品', 'KOR': '해금 물품 새로고침', 'Name': 'UI_RedSoul_ShowUnlock'},
#  {'CHT': '<color=#CB484B>勸君莫停</color>',
#   'KOR': '<color=#CB484B>진군불식</color>',
#   'Name': 'Trail_Name_1'},
#  {'CHT': '<color=#CB484B>以瞬代步</color>',
#   'KOR': '<color=#CB484B>즉시이동</color>',
#   'Name': 'Trail_Name_2'},
#  {'CHT': '<color=#CB484B>貪婪吞噬</color>',
#   'KOR': '<color=#CB484B>탐식</color>',
#   'Name': 'Trail_Name_3'},
#  {'CHT': '<color=#CB484B>顫慄夢魘</color>',
#   'KOR': '<color=#CB484B>전율몽염</color>',
#   'Name': 'Trail_Name_4'},
#  {'CHT': '<color=#CB484B>屍山血海</color>',
#   'KOR': '<color=#CB484B>시산혈해</color>',
#   'Name': 'Trail_Name_5'},
#  {'CHT': '<color=#CB484B>天干物燥</color>',
#   'KOR': '<color=#CB484B>천지건조</color>',
#   'Name': 'Trail_Name_6'},
#  {'CHT': '<color=#CB484B>五行不破</color>',
#   'KOR': '<color=#CB484B>오행불파</color>',
#   'Name': 'Trail_Name_7'},
#  {'CHT': '<color=#CB484B>體弱多病</color>',
#   'KOR': '<color=#CB484B>병약체질</color>',
#   'Name': 'Trail_Name_8'},
#  {'CHT': '<color=#CB484B>急走瘋狂</color>',
#   'KOR': '<color=#CB484B>광속질주</color>',
#   'Name': 'Trail_Name_9'},
#  {'CHT': '<color=#CB484B>赤紅血疫</color>',
#   'KOR': '<color=#CB484B>적혈병</color>',
#   'Name': 'Trail_Name_10'},
#  {'CHT': '玩家進入戰鬥後會隨著時間損失生命值，生命越多損失越快，獲得10%的所有傷害吸血。',
#   'KOR': '게임 시작 후 시간이 지날수록 생명력을 잃습니다. 생명력이 많을수록 소모량이 커지지만 모든 피해의 10%를 생명력으로 '
#          '흡혈합니다.',
#   'Name': 'Trail_Desc_1'},
#  {'CHT': '玩家移速減慢80%(無法再獲得移速加成），延長瞬身距離與無敵時間。',
#   'KOR': '이동 속도가 80% 감소하며 이동 속도 상승 효과가 사라지지만 질주 거리와 무적 상태의 지속 시간이 증가합니다.',
#   'Name': 'Trail_Desc_2'},
#  {'CHT': '所有怪物獲得吸血能力，小怪成功命中玩家恢復12%的生命，首領命中玩家恢復5%的生命',
#   'KOR': '모든 괴물이 흡혈 능력을 얻습니다. 일반 적이 플레이어를 성공적으로 공격하면 생명력의 12%를 회복하고, 우두머리가 '
#          '플레이어를 공격하면 생명력의 5%를 회복합니다.',
#   'Name': 'Trail_Desc_3'},
#  {'CHT': '首領的生命提高50%，造成的傷害提高40%。',
#   'KOR': '우두머리의 생명력이 50%, 피해가 40% 증가합니다.',
#   'Name': 'Trail_Desc_4'},
#  {'CHT': '所有非首領的怪物生命提高100%，造成的傷害提高30%。',
#   'KOR': '우두머리가 아닌 모든 적의 생명력이 100%, 피해가 30% 증가합니다.',
#   'Name': 'Trail_Desc_5'},
#  {'CHT': '所有怪物受到的近戰與飛劍傷害降低50%，受到的屬性傷害提升25%',
#   'KOR': '모든 적에게 주는 근접 및 비검 공격의 피해가 50% 감소하지만 속성 피해가 25% 증가합니다.',
#   'Name': 'Trail_Desc_6'},
#  {'CHT': '所有怪物受到的屬性傷害降低50%，受到的近戰與飛劍傷害提升25%',
#   'KOR': '모든 적에게 주는 속성 피해가 50% 감소하지만 근접 및 비검 공격의 피해가 25% 증가합니다.',
#   'Name': 'Trail_Desc_7'},
#  {'CHT': '玩家生命上限降低50%，受到的所有傷害提高20%',
#   'KOR': '당신의 최대 생명력이 50% 감소하고 모든 받는 피해가 20% 증가합니다.',
#   'Name': 'Trail_Desc_8'},
#  {'CHT': '所有非首領敵人的移動速度提高25%',
#   'KOR': '우두머리가 아닌 모든 적의 이동 속도가 25% 증가합니다.',
#   'Name': 'Trail_Desc_9'},
#  {'CHT': '普通敵人死亡0.5秒後會發生半徑1.5米範圍的鮮血爆炸，對玩家造成10%生命上限真實傷害，並附加5秒流血效果。',
#   'KOR': '일반 적이 사망하면 0.5초 후 반경 1.5미터 범위로 피의 폭발이 일어납니다. 폭발은 플레이어의 최대 생명력의 10%에 '
#          '해당하는 고정 피해를 입히고 5초간 출혈 상태를 부여합니다.',
#   'Name': 'Trail_Desc_10'},
#  {'CHT': '直到下次抵達中轉站，攻擊力提高30%。',
#   'KOR': '다음 경유지에 도달할 때까지 공격력이 30% 증가합니다.',
#   'Name': 'COP_Desc_0'},
#  {'CHT': '直到下次抵達中轉站，獲取藍魂量提高100%',
#   'KOR': '다음 경유지에 도달할 때까지 푸른 혼 획득량이 100% 증가합니다.',
#   'Name': 'COP_Desc_1'},
#  {'CHT': '直到下次抵達中轉站，不再出現觸手',
#   'KOR': '다음 경유지에 도달할 때까지 촉수가 나타나지 않습니다.',
#   'Name': 'COP_Desc_2'},
#  {'CHT': '直到下次抵達中轉站，敵人攻擊力變為50%',
#   'KOR': '다음 경유지에 도달할 때까지 적의 공격력이 50% 감소합니다.',
#   'Name': 'COP_Desc_3'},
#  {'CHT': '直到下次抵達中轉站，敵人血量降低30%',
#   'KOR': '다음 경유지에 도달할 때까지 적의 생명력이 30% 감소합니다.',
#   'Name': 'COP_Desc_4'},
#  {'CHT': '直到下次抵達中轉站，受到的遠程傷害降低50%',
#   'KOR': '다음 경유지에 도달할 때까지 원거리 피해가 50% 감소합니다.',
#   'Name': 'COP_Desc_5'},
#  {'CHT': '直到下次抵達中轉站，屬性傷害提高30%',
#   'KOR': '다음 경유지에 도달할 때까지 가하는 속성 피해가 30% 증가합니다.',
#   'Name': 'COP_Desc_6'},
#  {'CHT': '直到下次抵達中轉站，額外造成50%真實傷害',
#   'KOR': '다음 경유지에 도달할 때까지 50%의 고정 피해가 추가됩니다.',
#   'Name': 'COP_Desc_7'},
#  {'CHT': '直到下次抵達中轉站，受到的近戰傷害降低30%',
#   'KOR': '다음 경유지에 도달할 때까지 받는 근접 피해가 30% 감소합니다.',
#   'Name': 'COP_Desc_8'},
#  {'CHT': '直到下次抵達中轉站，非首領怪物攻擊力提高100%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時獲得2本<color=#E57E00>秘笈</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 공격력이 100% 증가합니다. <color=#89E7A0>보상: 다음 '
#          '경유지 도착 시 <color=#E57E00>종파 비급</color> 2권을 획득합니다.</color>',
#   'Name': 'COP_Desc_9'},
#  {'CHT': '直到下次抵達中轉站，非首領怪物攻擊力提高20%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時獲得1本<color=#E57E00>秘笈</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 공격력이 20% 증가합니다. <color=#89E7A0>보상: 다음 '
#          '경유지 도착 시 <color=#E57E00>종파 비급</color> 1권을 획득합니다.</color>',
#   'Name': 'COP_Desc_10'},
#  {'CHT': '直到下次抵達中轉站，非首領怪物生命提高40%\n<color=#89E7A0>獎勵：下次抵達中轉站時獲得大量藍魂。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 생명력이 40% 증가합니다. <color=#89E7A0>보상: 다음 '
#          '경유지 도착 시 푸른 혼을 대략 획득합니다.</color>',
#   'Name': 'COP_Desc_11'},
#  {'CHT': '直到下次抵達中轉站，非首領怪物攻擊力提高50%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時隨機獲得一個<color=#E57E00>傳說聖物</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 공격력이 50% 증가합니다. <color=#89E7A0>보상: 다음 '
#          '경유지 도착 시 무작위 <color=#E57E00>전설 등급 성물</color> 1개를 획득합니다.</color>',
#   'Name': 'COP_Desc_12'},
#  {'CHT': '直到下次抵達中轉站，非首領怪物生命提高20%，攻擊力提高20%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局攻擊力提升15%。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 생명력과 공격력이 20% 증가합니다. <color=#89E7A0>보상: '
#          '다음 경유지 도착 시 이번 게임 동안 내 공격력이 15% 증가합니다.</color>',
#   'Name': 'COP_Desc_13'},
#  {'CHT': '直到下次抵達中轉站，非首領怪物攻擊力提高20%，移動速度提高20%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局屬性傷害提高15%。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 공격력과 이동 속도가 20% 증가합니다. '
#          '<color=#89E7A0>보상: 다음 경유지 도착 시 이번 게임 동안 내가 주는 속성 피해가 15% '
#          '증가합니다.</color>',
#   'Name': 'COP_Desc_14'},
#  {'CHT': '直到下次抵達中轉站，敵人血量增加30%\n<color=#89E7A0>獎勵：下次抵達中轉站時，本局防禦力提升10%。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 적의 생명력이 30% 증가합니다. <color=#89E7A0>보상: 다음 경유지 도착 시 이번 '
#          '게임 동안 내 방어력이 10% 증가합니다.</color>',
#   'Name': 'COP_Desc_15'},
#  {'CHT': '直到下次抵達中轉站，敵人血量與攻擊力提升30%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局每次攻擊附帶30%攻擊力的<color=#E35428>火焰傷害</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 적의 생명력과 공격력이 30% 증가합니다. <color=#89E7A0>보상: 다음 경유지 도착 '
#          '시 이번 게임 동안 내 모든 공격에 공격력의 30%에 해당하는 <color=#E35428>화염 피해</color>가 '
#          '추가됩니다.</color>',
#   'Name': 'COP_Desc_16'},
#  {'CHT': '直到下次抵達中轉站，敵人血量與攻擊力提升30%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局每次攻擊附帶30%攻擊力的<color=#73D7F1>冰霜傷害</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 적의 생명력과 공격력이 30% 증가합니다. <color=#89E7A0>보상: 다음 경유지 도착 '
#          '시 이번 게임 동안 내 모든 공격에 공격력의 30%에 해당하는 <color=#73D7F1>빙결 피해</color>가 '
#          '추가됩니다.</color>',
#   'Name': 'COP_Desc_17'},
#  {'CHT': '直到下次抵達中轉站，敵人血量與攻擊力提升30%\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局每次攻擊附帶30%攻擊力的<color=#F3ED56>閃電傷害</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 적의 생명력과 공격력이 30% 증가합니다. <color=#89E7A0>보상: 다음 경유지 도착 '
#          '시 이번 게임 동안 내 모든 공격에 공격력의 30%에 해당하는 <color=#F3ED56>전격 피해</color>가 '
#          '추가됩니다.</color>',
#   'Name': 'COP_Desc_18'},
#  {'CHT': '<color=#66BAD2>強化</color>',
#   'KOR': '<color=#66BAD2>강화</color>',
#   'Name': 'PowerUp_Title'},
#  {'CHT': '<color=#AB28FF>挑戰</color>',
#   'KOR': '<color=#AB28FF>도전</color>',
#   'Name': 'Challenge_Title'},
#  {'CHT': '獎勵:\n通關遊戲後獲得紅魂*{0}\n本局藍魂掉落量提高{1}%',
#   'KOR': '보상: 게임 클리어 시 붉은 혼 ×{0} 획득 현재 게임 내 푸른 혼 획득량 {1}% 증가',
#   'Name': 'Trial_Award'},
#  {'CHT': '<color=#CB484B>試煉・</color>',
#   'KOR': '<color=#CB484B>시련・</color>',
#   'Name': 'Trial_Title'},
#  {'CHT': '<color=#CB484B><size=31>鋸齒牙刃</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・牙刃</color>*1\n'
#          '<color=#E57E00>傳說・鋒銳之牙</color>*1\n'
#          '<color=#E57E00>傳說・變異殘肢</color>*1',
#   'KOR': '<color=#CB484B><size=31>톱니 송곳니</size></color> 포함 물품: '
#          '<color=#CB484B>신화・송곳니</color> ×1 <color=#E57E00>전설 날카로운 송곳니</color> '
#          '×1 <color=#E57E00>전설 변이 수족</color> ×1',
#   'Name': 'Suit_Name_1'},
#  {'CHT': '<color=#CB484B><size=31>飛刃空明</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・空明</color>*1\n'
#          '<color=#E57E00>傳說・凝氣草</color>*1\n'
#          '<color=#E57E00>傳說・狂暴之血</color>*1',
#   'KOR': '<color=#CB484B><size=31>망각검</size></color> 포함 물품: '
#          '<color=#CB484B>신화・망각</color> ×1 <color=#E57E00>전설 기통초</color> ×1 '
#          '<color=#E57E00>전설 광기혈</color> ×1',
#   'Name': 'Suit_Name_2'},
#  {'CHT': '<color=#CB484B><size=31>劇毒青蛇</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・青蛇</color>*1\n'
#          '<color=#E57E00>傳說・屍變斷指</color>*1\n'
#          '<color=#E57E00>傳說・雄黃</color>*1',
#   'KOR': '<color=#CB484B><size=31>맹독사</size></color> 포함 물품: '
#          '<color=#CB484B>신화・청사</color> ×1 <color=#E57E00>전설 좀비 손가락</color> ×1 '
#          '<color=#E57E00>전설 웅황</color> ×1',
#   'Name': 'Suit_Name_3'},
#  {'CHT': '<color=#CB484B><size=31>冰封細劍</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・霜降</color>*1\n'
#          '<color=#E57E00>傳說・千年寒冰</color>*2',
#   'KOR': '<color=#CB484B><size=31>빙결검</size></color> 포함 물품: '
#          '<color=#CB484B>신화・상강</color> ×1 <color=#E57E00>전설 만년빙정</color> ×2',
#   'Name': 'Suit_Name_4'},
#  {'CHT': '<color=#CB484B><size=31>花瓣飛舞</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・凋零</color>*1\n'
#          '<color=#E57E00>傳說・死之蓮</color>*1\n'
#          '<color=#E57E00>傳說・須臾之沙</color>*1',
#   'KOR': '<color=#CB484B><size=31>비행 꽃잎</size></color> 포함 물품: '
#          '<color=#CB484B>신화・순환</color> ×1 <color=#E57E00>전설 죽음의 연꽃</color> ×1 '
#          '<color=#E57E00>전설 무상의 모래</color> ×1',
#   'Name': 'Suit_Name_5'},
#  {'CHT': '<color=#CB484B><size=31>墨火炎刃</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・墨炎</color>*1\n'
#          '<color=#E57E00>傳說・墨火結晶</color>*1\n'
#          '<color=#E57E00>傳說・火硝石</color>*1',
#   'KOR': '<color=#CB484B><size=31>묵화검</size></color> 포함 물품: '
#          '<color=#CB484B>신화・묵염</color> ×1 <color=#E57E00>전설 묵화 수정</color> ×1 '
#          '<color=#E57E00>전설 화초석</color> ×1',
#   'Name': 'Suit_Name_6'},
#  {'CHT': '<color=#CB484B><size=31>醉酒爆燃</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・流火</color>*1\n'
#          '<color=#E57E00>傳說・醉仙釀</color>*1\n'
#          '<color=#E57E00>傳說・火硝石</color>*1',
#   'KOR': '<color=#CB484B><size=31>만취 폭연</size></color> 포함 물품: '
#          '<color=#CB484B>신화・유염</color> ×1 <color=#E57E00>전설 취선주</color> ×1 '
#          '<color=#E57E00>전설 화초석</color> ×1',
#   'Name': 'Suit_Name_7'},
#  {'CHT': '<color=#CB484B><size=31>破冰巨斧</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・碎冰</color>*1\n'
#          '<color=#E57E00>傳說・破冰石</color>*1\n'
#          '<color=#E57E00>傳說・千年寒冰</color>*1',
#   'KOR': '<color=#CB484B><size=31>쇄빙부</size></color> 포함 물품: '
#          '<color=#CB484B>신화・쇄빙</color> ×1 <color=#E57E00>전설 쇠빙석</color> ×1 '
#          '<color=#E57E00>만년빙정</color> ×1',
#   'Name': 'Suit_Name_8'},
#  {'CHT': '<color=#CB484B><size=31>繽紛雪蓮</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・雪蓮</color>*1\n'
#          '<color=#E57E00>傳說・死之蓮</color>*1\n'
#          '<color=#E57E00>傳說・北風花</color>*1',
#   'KOR': '<color=#CB484B><size=31>백설련</size></color> 포함 물품: '
#          '<color=#CB484B>신화・설련</color> ×1 <color=#E57E00>전설 죽음의 연꽃</color> ×1 '
#          '<color=#E57E00>전설 북풍화</color> ×1',
#   'Name': 'Suit_Name_9'},
#  {'CHT': '<color=#CB484B><size=31>天地道法</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・冥將</color>*1\n'
#          '<color=#E57E00>傳說・黃紙</color>*1\n'
#          '<color=#E57E00>傳說・踏風草</color>*1',
#   'KOR': '<color=#CB484B><size=31>천지도법</size></color> 포함 물품: '
#          '<color=#CB484B>신화・명계의 장수</color> ×1 <color=#E57E00>전설 부적</color> ×1 '
#          '<color=#E57E00>전설 답풍초</color> ×1',
#   'Name': 'Suit_Name_10'},
#  {'CHT': '<color=#CB484B><size=31>嗜血狼王</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・狼王</color>*1\n'
#          '<color=#E57E00>傳說・鋒銳之牙</color>*1\n'
#          '<color=#E57E00>傳說・狼王白鬃</color>*1',
#   'KOR': '<color=#CB484B><size=31>탐혈 낭왕</size></color> 포함 물품: '
#          '<color=#CB484B>신화・낭왕</color> ×1 <color=#E57E00>전설 날카로운 송곳니</color> '
#          '×1 <color=#E57E00>전설 백설 갈기</color> ×1',
#   'Name': 'Suit_Name_11'},
#  {'CHT': '<color=#CB484B><size=31>在世華佗</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・華佗</color>*1\n'
#          '<color=#E57E00>傳說・血靈芝</color>*1\n'
#          '<color=#E57E00>傳說・跌打草</color>*1',
#   'KOR': '<color=#CB484B><size=31>세기의 화타</size></color> 포함 물품: '
#          '<color=#CB484B>신화・화타</color> ×1 <color=#E57E00>전설 핏빛 영지버섯</color> ×1 '
#          '<color=#E57E00>전설 진정초</color> ×1',
#   'Name': 'Suit_Name_12'},
#  {'CHT': '<color=#CB484B><size=31>太祖之怒</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・太祖</color>*1\n'
#          '<color=#E57E00>傳說・白虎之魂</color>*1\n'
#          '<color=#E57E00>傳說・憎恨之心</color>*1',
#   'KOR': '<color=#CB484B><size=31>선조의 분노</size></color> 포함 물품: '
#          '<color=#CB484B>신화・선조</color> ×1 <color=#E57E00>전설 백호의 혼</color> ×1 '
#          '<color=#E57E00>전설 증오의 심장</color> ×1',
#   'Name': 'Suit_Name_13'},
#  {'CHT': '<color=#CB484B><size=31>怒火中燒</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・暴怒</color>*1\n'
#          '<color=#E57E00>傳說・狂暴之血</color>*1\n'
#          '<color=#E57E00>傳說・須臾之沙</color>*1',
#   'KOR': '<color=#CB484B><size=31>끓어오르는 분노</size></color> 포함 물품: '
#          '<color=#CB484B>신화・격분</color> ×1 <color=#E57E00>전설 광기혈</color> ×1 '
#          '<color=#E57E00>전설 무상의 모래</color> ×1',
#   'Name': 'Suit_Name_14'},
#  {'CHT': '<color=#CB484B><size=31>山崩地裂</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・山崩</color>*1\n'
#          '<color=#E57E00>傳說・大骨</color>*1\n'
#          '<color=#E57E00>傳說・破冰石</color>*1',
#   'KOR': '<color=#CB484B><size=31>파괴의 균열</size></color> 포함 물품: '
#          '<color=#CB484B>신화・산사태</color> ×1 <color=#E57E00>전설 커다란 뼈</color> ×1 '
#          '<color=#E57E00>전설 쇄빙석</color> ×1',
#   'Name': 'Suit_Name_15'},
#  {'CHT': '<color=#CB484B><size=31>火焰龍卷</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・風火</color>*1\n'
#          '<color=#E57E00>傳說・火硝石</color>*1\n'
#          '<color=#E57E00>傳說・凝氣草</color>*1',
#   'KOR': '<color=#CB484B><size=31>불꽃 회오리</size></color> 포함 물품: '
#          '<color=#CB484B>신화・불폭풍</color> ×1 <color=#E57E00>전설 화초석</color> ×1 '
#          '<color=#E57E00>전설 기통초</color> ×1',
#   'Name': 'Suit_Name_16'},
#  {'CHT': '<color=#CB484B><size=31>血色冥妝</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・冥妝</color>*1\n'
#          '<color=#E57E00>傳說・鬼妃斷發</color>*1\n'
#          '<color=#E57E00>傳說・水銀</color>*1',
#   'KOR': '<color=#CB484B><size=31>핏의 부조</size></color> 포함 물품: '
#          '<color=#CB484B>신화・부조</color> ×1 <color=#E57E00>전설 망령의 가닥</color> ×1 '
#          '<color=#E57E00>전설 수은</color> ×1',
#   'Name': 'Suit_Name_17'},
#  {'CHT': '<color=#CB484B><size=31>大三元</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・三元</color>*1\n'
#          '<color=#E57E00>傳說・三色結晶</color>*1\n'
#          '<color=#E57E00>傳說・黃紙</color>*1',
#   'KOR': '<color=#CB484B><size=31>대삼재</size></color> 포함 물품: '
#          '<color=#CB484B>신화・삼재</color> ×1 <color=#E57E00>전설 삼색 수정</color> ×1 '
#          '<color=#E57E00>전설 부적</color> ×1',
#   'Name': 'Suit_Name_18'},
#  {'CHT': '<color=#CB484B><size=31>深冬極寒</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・深冬</color>*1\n'
#          '<color=#E57E00>傳說・北風花</color>*1\n'
#          '<color=#E57E00>傳說・千年寒冰</color>*1',
#   'KOR': '<color=#CB484B><size=31>엄동설한</size></color> 포함 물품: '
#          '<color=#CB484B>신화・동장군</color> ×1 <color=#E57E00>전설 북풍화</color> ×1 '
#          '<color=#E57E00>전설 만년빙정</color> ×1',
#   'Name': 'Suit_Name_19'},
#  {'CHT': '<color=#CB484B><size=31>雷霆之力</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・驚蟄</color>*1\n'
#          '<color=#E57E00>傳說・引雷鎖</color>*1\n'
#          '<color=#E57E00>傳說・響雷石</color>*1',
#   'KOR': '<color=#CB484B><size=31>천둥의 힘</size></color> 포함 물품: '
#          '<color=#CB484B>신화・초뢰</color> ×1 <color=#E57E00>전설 번개 족쇄</color> ×1 '
#          '<color=#E57E00>전설 뇌석</color> ×1',
#   'Name': 'Suit_Name_20'},
#  {'CHT': '<color=#CB484B><size=31>彈指之間</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・須臾</color>*1\n'
#          '<color=#E57E00>傳說・須臾之沙</color>*2',
#   'KOR': '<color=#CB484B><size=31>찰나</size></color> 포함 물품: '
#          '<color=#CB484B>신화・금세</color> ×1 <color=#E57E00>전설 무상의 모래</color> ×2',
#   'Name': 'Suit_Name_21'},
#  {'CHT': '<color=#CB484B><size=48>永恆之焰\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・永焰</color>*1\n'
#          '<color=#E57E00>傳說・飛硝箭</color>*1\n'
#          '<color=#E57E00>傳說・黑火藥</color>*1',
#   'KOR': '<color=#CB484B><size=48>영항지염\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・영염</color>*1\n'
#          '<color=#E57E00>전설・비초전</color>*1\n'
#          '<color=#E57E00>전설・흑화약</color>*1',
#   'Name': 'Suit_Name_22'},
#  {'CHT': '<color=#CB484B><size=48>毒瀧惡霧\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・毒淵</color>*1\n'
#          '<color=#E57E00>傳說・毒囊</color>*1\n'
#          '<color=#E57E00>傳說・水銀</color>*1',
#   'KOR': '<color=#CB484B><size=48>독롱악무\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・독연</color>*1\n'
#          '<color=#E57E00>전설・독낭</color>*1\n'
#          '<color=#E57E00>전설・수은</color>*1',
#   'Name': 'Suit_Name_23'},
#  {'CHT': '<color=#CB484B><size=48>炮烙之刑\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・斷肢</color>*1\n'
#          '<color=#E57E00>傳說・變異殘肢</color>*1\n'
#          '<color=#E57E00>傳說・鳳凰喙</color>*1',
#   'KOR': '<color=#CB484B><size=48>포락지형\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・단지</color>*1\n'
#          '<color=#E57E00>전설・변이잔지</color>*1\n'
#          '<color=#E57E00>전설・봉황훼</color>*1',
#   'Name': 'Suit_Name_24'},
#  {'CHT': '<color=#CB484B><size=48>禦劍之術\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・飛瀑</color>*1\n'
#          '<color=#E57E00>傳說・靈玉</color>*2',
#   'KOR': '<color=#CB484B><size=48>어검지술\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・비폭</color>*1\n'
#          '<color=#E57E00>전설・영옥</color>*2',
#   'Name': 'Suit_Name_25'},
#  {'CHT': '<color=#CB484B><size=48>帶毒之刃\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・碧水</color>*1\n'
#          '<color=#E57E00>傳說・水銀</color>*1\n'
#          '<color=#E57E00>傳說・鸊鵜膏</color>*1',
#   'KOR': '<color=#CB484B><size=48>극독지인\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・벽수</color>*1\n'
#          '<color=#E57E00>전설・수은</color>*1\n'
#          '<color=#E57E00>전설・벽제고</color>*1',
#   'Name': 'Suit_Name_26'},
#  {'CHT': '<color=#CB484B><size=48>倒地不起\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・芳華</color>*1\n'
#          '<color=#E57E00>傳說・生命之種</color>*1\n'
#          '<color=#E57E00>傳說・重山鎧</color>*1',
#   'KOR': '<color=#CB484B><size=48>재기불능\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・방화</color>*1\n'
#          '<color=#E57E00>전설・생명지종</color>*1\n'
#          '<color=#E57E00>전설・중산개</color>*1',
#   'Name': 'Suit_Name_27'},
#  {'CHT': '<color=#CB484B><size=48>首尾呼應\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・始末</color>*1\n'
#          '<color=#E57E00>傳說・玄詭刃</color>*1\n'
#          '<color=#E57E00>傳說・鵜鶘膏</color>*1',
#   'KOR': '<color=#CB484B><size=48>수미호응\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・시말</color>*1\n'
#          '<color=#E57E00>전설・현궤인</color>*1\n'
#          '<color=#E57E00>전설・제호고</color>*1',
#   'Name': 'Suit_Name_28'},
#  {'CHT': '<color=#CB484B><size=48>仙風道骨\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・藥仙</color>*1\n'
#          '<color=#E57E00>傳說・跌打草</color>*1\n'
#          '<color=#E57E00>傳說・狂將鎖</color>*1',
#   'KOR': '<color=#CB484B><size=48>선풍도골\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・약선</color>*1\n'
#          '<color=#E57E00>전설・질타초</color>*1\n'
#          '<color=#E57E00>전설・광장쇄</color>*1',
#   'Name': 'Suit_Name_29'},
#  {'CHT': '<color=#CB484B><size=48>斬鋼截鐵\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・斬鐵</color>*1\n'
#          '<color=#E57E00>傳說・青鋼</color>*1\n'
#          '<color=#E57E00>傳說・玄詭刃</color>*1',
#   'KOR': '<color=#CB484B><size=48>참강절철\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・참철</color>*1\n'
#          '<color=#E57E00>전설・청강</color>*1\n'
#          '<color=#E57E00>전설・현궤인</color>*1',
#   'Name': 'Suit_Name_30'},
#  {'CHT': '<color=#CB484B><size=48>風馳電掣\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・風起</color>*1\n'
#          '<color=#E57E00>傳說・猛虎之印</color>*1\n'
#          '<color=#E57E00>傳說・須臾之沙</color>*1',
#   'KOR': '<color=#CB484B><size=48>풍치전철\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・풍기</color>*1\n'
#          '<color=#E57E00>전설・맹호지인</color>*1\n'
#          '<color=#E57E00>전설・수유지사</color>*1',
#   'Name': 'Suit_Name_31'},
#  {'CHT': '<color=#CB484B><size=48>青龍出海\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・孟章</color>*1\n'
#          '<color=#E57E00>傳說・墮龍</color>*1\n'
#          '<color=#E57E00>傳說・青龍之魂</color>*1',
#   'KOR': '<color=#CB484B><size=48>청룡출해\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・맹장</color>*1\n'
#          '<color=#E57E00>전설・타룡</color>*1\n'
#          '<color=#E57E00>전설・청룡지혼</color>*1',
#   'Name': 'Suit_Name_32'},
#  {'CHT': '<color=#CB484B><size=48>朱雀展翅\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・陵光</color>*1\n'
#          '<color=#E57E00>傳說・墮龍</color>*1\n'
#          '<color=#E57E00>傳說・朱雀之魂</color>*1',
#   'KOR': '<color=#CB484B><size=48>주작전시\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・능광</color>*1\n'
#          '<color=#E57E00>전설・타룡</color>*1\n'
#          '<color=#E57E00>전설・주작지혼</color>*1',
#   'Name': 'Suit_Name_33'},
#  {'CHT': '<color=#CB484B><size=48>白虎穿堂\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・監兵</color>*1\n'
#          '<color=#E57E00>傳說・墮龍</color>*1\n'
#          '<color=#E57E00>傳說・白虎之魂</color>*1',
#   'KOR': '<color=#CB484B><size=48>백호천당\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・감병</color>*1\n'
#          '<color=#E57E00>전설・타룡</color>*1\n'
#          '<color=#E57E00>전설・백호지혼</color>*1',
#   'Name': 'Suit_Name_34'},
#  {'CHT': '<color=#CB484B><size=48>玄武插尾\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・執明</color>*1\n'
#          '<color=#E57E00>傳說・墮龍</color>*1\n'
#          '<color=#E57E00>傳說・玄武之魂</color>*1',
#   'KOR': '<color=#CB484B><size=48>현무삽미\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・집명</color>*1\n'
#          '<color=#E57E00>전설・타룡</color>*1\n'
#          '<color=#E57E00>전설・현무지혼</color>*1',
#   'Name': 'Suit_Name_35'},
#  {'CHT': '<color=#CB484B><size=48>初始裝備\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・鐵劍</color>*1\n'
#          '<color=#E57E00>傳說・疑無物</color>*2',
#   'KOR': '<color=#CB484B><size=48>초기장비\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・철검</color>*1\n'
#          '<color=#E57E00>전설・의심스런 무언가</color>*2',
#   'Name': 'Suit_Name_36'},
#  {'CHT': '<color=#CB484B><size=48>棄惡從善\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・同心</color>*1\n'
#          '<color=#E57E00>傳說・摯愛之心</color>*2',
#   'KOR': '<color=#CB484B><size=48>기악종선\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・동심</color>*1\n'
#          '<color=#E57E00>전설・지애지심</color>*2',
#   'Name': 'Suit_Name_37'},
#  {'CHT': '<color=#CB484B><size=48>鹹魚之力\n'
#          '</size></color>\n'
#          '包含以下物品：\n'
#          '<color=#CB484B>絕世・躺平</color>*1\n'
#          '<color=#E57E00>傳說・母神舊印</color>*1\n'
#          '<color=#E57E00>傳說・長夢霧靄</color>*1',
#   'KOR': '<color=#CB484B><size=48>함어지력\n'
#          '</size></color>\n'
#          '포함 물품: \n'
#          '<color=#CB484B>절세・당평</color>*1\n'
#          '<color=#E57E00>전설・모신구인</color>*1\n'
#          '<color=#E57E00>전설・장몽무애</color>*1',
#   'Name': 'Suit_Name_38'},
#  {'CHT': '玄武之魂', 'KOR': '현무지혼', 'Name': 'PN_NAME_1'},
#  {'CHT': '白虎之魂', 'KOR': '백호지혼', 'Name': 'PN_NAME_2'},
#  {'CHT': '青龍之魂', 'KOR': '청룡지혼', 'Name': 'PN_NAME_3'},
#  {'CHT': '朱雀之魂', 'KOR': '주작지혼', 'Name': 'PN_NAME_4'},
#  {'CHT': '屍變斷指', 'KOR': '강시의 손가락', 'Name': 'PN_NAME_5'},
#  {'CHT': '鋒銳之牙', 'KOR': '날카로운 송곳니', 'Name': 'PN_NAME_6'},
#  {'CHT': '跌打草', 'KOR': '진정초', 'Name': 'PN_NAME_7'},
#  {'CHT': '大骨', 'KOR': '큰 뼈', 'Name': 'PN_NAME_8'},
#  {'CHT': '珍珠', 'KOR': '진주', 'Name': 'PN_NAME_9'},
#  {'CHT': '雄黃', 'KOR': '웅황', 'Name': 'PN_NAME_10'},
#  {'CHT': '憎恨之心', 'KOR': '증오의 심장', 'Name': 'PN_NAME_11'},
#  {'CHT': '凝氣草', 'KOR': '기통초', 'Name': 'PN_NAME_12'},
#  {'CHT': '血玉髓', 'KOR': '혈옥수', 'Name': 'PN_NAME_13'},
#  {'CHT': '火硝石', 'KOR': '화초석', 'Name': 'PN_NAME_14'},
#  {'CHT': '醉仙釀', 'KOR': '취선주', 'Name': 'PN_NAME_15'},
#  {'CHT': '血靈芝', 'KOR': '혈영지', 'Name': 'PN_NAME_16'},
#  {'CHT': '千年寒冰', 'KOR': '천년한빙', 'Name': 'PN_NAME_17'},
#  {'CHT': '狼王白鬃', 'KOR': '낭왕의 흰 갈기', 'Name': 'PN_NAME_18'},
#  {'CHT': '死之蓮', 'KOR': '죽음의 연꽃', 'Name': 'PN_NAME_19'},
#  {'CHT': '狂暴之血', 'KOR': '광폭한 피', 'Name': 'PN_NAME_20'},
#  {'CHT': '踏風草', 'KOR': '답풍초', 'Name': 'PN_NAME_21'},
#  {'CHT': '破冰石', 'KOR': '파빙석', 'Name': 'PN_NAME_22'},
#  {'CHT': '須臾之沙', 'KOR': '순간의 모래', 'Name': 'PN_NAME_23'},
#  {'CHT': '墨火結晶', 'KOR': '묵화 결정', 'Name': 'PN_NAME_24'},
#  {'CHT': '星辰之玉', 'KOR': '성신옥', 'Name': 'PN_NAME_25'},
#  {'CHT': '動力核心', 'KOR': '동력핵', 'Name': 'PN_NAME_26'},
#  {'CHT': '機關炮輪', 'KOR': '기관총통', 'Name': 'PN_NAME_27'},
#  {'CHT': '機關噴口', 'KOR': '기관포신', 'Name': 'PN_NAME_28'},
#  {'CHT': '機關外殼', 'KOR': '기관외판', 'Name': 'PN_NAME_29'},
#  {'CHT': '黃紙', 'KOR': '황지', 'Name': 'PN_NAME_30'},
#  {'CHT': '北風花', 'KOR': '북풍화', 'Name': 'PN_NAME_31'},
#  {'CHT': '毒囊', 'KOR': '독낭', 'Name': 'PN_NAME_32'},
#  {'CHT': '鬼妃斷發', 'KOR': '귀비단발', 'Name': 'PN_NAME_33'},
#  {'CHT': '三色結晶', 'KOR': '삼색결정', 'Name': 'PN_NAME_34'},
#  {'CHT': '引雷鎖', 'KOR': '인뢰쇄', 'Name': 'PN_NAME_35'},
#  {'CHT': '變異殘肢', 'KOR': '변이 수족', 'Name': 'PN_NAME_36'},
#  {'CHT': '猛虎之印', 'KOR': '맹호의 인장', 'Name': 'PN_NAME_37'},
#  {'CHT': '墮龍', 'KOR': '타락 용', 'Name': 'PN_NAME_38'},
#  {'CHT': '響雷石', 'KOR': '향뢰석', 'Name': 'PN_NAME_39'},
#  {'CHT': '黑火藥', 'KOR': '흑화약', 'Name': 'PN_NAME_40'},
#  {'CHT': '水銀', 'KOR': '수은', 'Name': 'PN_NAME_41'},
#  {'CHT': '青鋼', 'KOR': '청강', 'Name': 'PN_NAME_42'},
#  {'CHT': '靈玉', 'KOR': '영옥', 'Name': 'PN_NAME_43'},
#  {'CHT': '鎮山石', 'KOR': '진산석', 'Name': 'PN_NAME_44'},
#  {'CHT': '生命之種', 'KOR': '생명의 씨앗', 'Name': 'PN_NAME_45'},
#  {'CHT': '飛硝箭', 'KOR': '비초살', 'Name': 'PN_NAME_46'},
#  {'CHT': '恐懼之心', 'KOR': '공포의 심장', 'Name': 'PN_NAME_47'},
#  {'CHT': '龍形觥', 'KOR': '용형궤', 'Name': 'PN_NAME_48'},
#  {'CHT': '鸊鵜膏', 'KOR': '벽제고', 'Name': 'PN_NAME_49'},
#  {'CHT': '異星之石', 'KOR': '이성석', 'Name': 'PN_NAME_50'},
#  {'CHT': '疑無物', 'KOR': '의심스런 무언가', 'Name': 'PN_NAME_51'},
#  {'CHT': '鳳凰喙', 'KOR': '봉황훼', 'Name': 'PN_NAME_52'},
#  {'CHT': '淵龍牙', 'KOR': '연룡아', 'Name': 'PN_NAME_53'},
#  {'CHT': '北冥石', 'KOR': '북명석', 'Name': 'PN_NAME_54'},
#  {'CHT': '玄詭刃', 'KOR': '현궤인', 'Name': 'PN_NAME_55'},
#  {'CHT': '重山鎧', 'KOR': '중산갑', 'Name': 'PN_NAME_56'},
#  {'CHT': '<size=17><b>・</b>防禦+5%\n<b>・</b>防禦每提高1%，使你造成的所有傷害提高1%。</size>',
#   'KOR': '<size=17><b>・</b>방어력 +5% <b>・</b>방어력이 1% 오를 때마다 가하는 모든 피해가 1% '
#          '증가합니다.</size>',
#   'Name': 'PN_DESC_1_0_0'},
#  {'CHT': '<size=17><b>・</b><color=#4C8FEA>瞬身時：</color>使你受到的治療效果提高15%，持續3秒。</size>',
#   'KOR': '<size=17><b>・</b><color=#4C8FEA>질주 시</color> 3초간 회복 효과가 15% '
#          '증가합니다.</size>',
#   'Name': 'PN_DESC_1_1_0'},
#  {'CHT': '<size=17><b>・</b>防禦+7%</size>',
#   'KOR': '<size=17><b>・</b>방어력 +7%</size>',
#   'Name': 'PN_DESC_1_2_0'},
#  {'CHT': '<size=17><b>・</b><color=#70DE9E>受到致命傷時：</color>使你的生命無法降低到5%以下，該效果發動後需要施放怒氣技能後才能再次觸發。\n'
#          '<b>・</b><color=#C83E48>怒氣達到100時：</color>對周圍發動玄武震擊，造成{atk*4}點傷害。</size>',
#   'KOR': '<size=17><b>・</b><color=#70DE9E>치명상을 입으면</color> 생명력이 5% 미만으로 떨어지지 '
#          '않도록 보호 효과가 발동됩니다. 이 효과는 분노 기술을 쓴 이후에 다시 활성화됩니다. '
#          '<b>・</b><color=#C83E48>분노 100 달성 시</color> 주변 범위에 현무 진격을 시전하여 '
#          '{atk*4}의 피해를 줍니다.</size>',
#   'Name': 'PN_DESC_1_3_0'},
#  {'CHT': '<size=17><b>・</b>防禦+10%\n<b>・</b>防禦每提高1%，使你造成的所有傷害提高1.5%。</size>',
#   'KOR': '<size=17><b>・</b>방어력 +10% <b>・</b>방어력이 1.5% 오를 때마다 가하는 모든 피해가 1% '
#          '증가합니다.</size>',
#   'Name': 'PN_DESC_1_0_1'},
#  {'CHT': '<size=17><b>・</b><color=#4C8FEA>瞬身時：</color>使你受到的治療效果提高30%，持續3秒。</size>',
#   'KOR': '<size=17><b>・</b><color=#4C8FEA>질주 시</color> 3초간 회복 효과가 30% '
#          '증가합니다.</size>',
#   'Name': 'PN_DESC_1_1_1'},
#  {'CHT': '<size=17><b>・</b>防禦+14%\n'
#          '<b>・</b><color=#70DE9E>受擊時：</color>有5%幾率恢復5%的最大生命值。</size>',
#   'KOR': '<size=17><b>・</b>방어력 +14% <b>・</b><color=#70DE9E>피격 시</color> 5% 확률로 '
#          '전체 생명력의 5%를 회복합니다.</size>',
#   'Name': 'PN_DESC_1_2_1'},
#  {'CHT': '<size=17><b>・</b><color=#70DE9E>受到致命傷時：</color>使你的生命無法降低到10%以下，該效果發動後需要施放怒氣技能後才能再次觸發。\n'
#          '<b>・</b><color=#C83E48>怒氣達到100時：</color>對周圍發動玄武震擊，造成{atk*6}點傷害。\n'
#          '<b>・</b>玄武震擊每命中一個敵人，就會為你恢復1%的生命值。</size>',
#   'KOR': '<size=17><b>・</b><color=#70DE9E>치명상을 입으면</color> 생명력이 10% 미만으로 떨어지지 '
#          '않도록 보호 효과가 발동됩니다. 이 효과는 분노 기술을 쓴 이후에 다시 활성화됩니다. '
#          '<b>・</b><color=#C83E48>분노 100 달성 시</color> 주변 범위에 현무 진격을 시전하여 '
#          '{atk*6}의 피해를 줍니다. <b>・</b>적에게 현무진격이 적중할 때마다 생명력을 3% 회복합니다.</size>',
#   'Name': 'PN_DESC_1_3_1'},
#  {'CHT': '<size=17><b>・</b>防禦+10%\n'
#          '<b>・</b>防禦每提高1%，使你造成的所有傷害提高1.5%。\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>造成傷害時：</color>使你的防禦提高1%，持續3秒，最多疊加5層。</color></size>',
#   'KOR': '<size=17><b>・</b>방어력 +10% <b>・</b>방어력이 1.5% 오를 때마다 가하는 모든 피해가 1% '
#          '증가합니다. <color=#FB8204><b>・</b><color=#C83E48>적에게 피해를 입히면</color>방어력이 '
#          '3초간 1% 증가합니다. 이 효과는 최대 5회 중첩됩니다.</color></size>',
#   'Name': 'PN_DESC_1_0_2'},
#  {'CHT': '<size=17><b>・</b><color=#4C8FEA>瞬身時：</color>使你受到的治療效果提高45%，持續3秒。\n'
#          '<color=#FB8204><b>・</b>如果你的生命低於25%：受到的治療效果+15%，防禦+8%。</color></size>',
#   'KOR': '<size=17><b>・</b><color=#4C8FEA>질주 시</color>회복 효과가 3초간 45% 증가합니다. '
#          '<color=#FB8204><b>・</b>생명력이 25% 미만일 시 회복 효과 +15%, 방어력 '
#          '+8%</color></size>',
#   'Name': 'PN_DESC_1_1_2'},
#  {'CHT': '<size=17><b>・</b>防禦+14%\n'
#          '<b>・</b><color=#70DE9E>受擊時：</color>有10%的幾率恢復8%的最大生命值。\n'
#          '<color=#FB8204><b>・</b>如果你的生命低於40%：觸發幾率和治療量翻倍。</color></size>',
#   'KOR': '<size=17><b>・</b>방어력 +14% <b>・</b><color=#70DE9E>피격 시</color> 10% '
#          '확률로 전체 생명력의 8%를 회복합니다. <color=#FB8204><b>・</b>생명력이 40% 미만인 경우에 발동 '
#          '확률과 회복량이 2배로 적용됩니다.</color></size>',
#   'Name': 'PN_DESC_1_2_2'},
#  {'CHT': '<size=17><b>・</b><color=#70DE9E>受到致命傷時：</color>使你的生命無法降低到15%以下，該效果發動後需要施放怒氣技能後才能再次觸發。\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>怒氣達到100時：</color>對周圍發動強效玄武震擊，造成{atk*8}點傷害。\n'
#          '<b>・</b>玄武震擊每命中一個敵人，就會為你恢復3%的生命值。</color></size>',
#   'KOR': '<size=17><b>・</b><color=#70DE9E>치명상을 입으면</color> 생명력이 15% 미만으로 떨어지지 '
#          '않도록 보호 효과가 발동됩니다. 이 효과는 분노 기술을 쓴 이후에 다시 활성화됩니다. '
#          '<color=#FB8204><b>・</b><color=#C83E48>분노 100 달성 시</color> 주변 범위에 강화 '
#          '현무 진격을 시전하여 {atk*8}의 피해를 줍니다. <b>・</b>적에게 현무진격이 적중할 때마다 생명력을 3% '
#          '회복합니다.</color></size>',
#   'Name': 'PN_DESC_1_3_2'},
#  {'CHT': '<size=17><b>・</b>近戰攻擊+10%</size>',
#   'KOR': '<size=17><b>・</b>근접 공격 피해 +10%</size>',
#   'Name': 'PN_DESC_2_0_0'},
#  {'CHT': '<size=17><b>・</b>攻擊速度+7%\n<b>・</b>移動速度+5%</size>',
#   'KOR': '<size=17><b>・</b>공격 속도 +7% <b>・</b>이동 속도 +5%</size>',
#   'Name': 'PN_DESC_2_1_0'},
#  {'CHT': '<size=17><b>・</b>近戰攻擊+5%\n<b>・</b>防禦+4%</size>',
#   'KOR': '<size=17><b>・</b>근접 공격 피해 +5% <b>・</b>방어력 +4%</size>',
#   'Name': 'PN_DESC_2_2_0'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>近戰攻擊時：</color>有15%的幾率追加一次額外攻擊。\n'
#          '<b>・</b><color=#C83E48>怒氣達到100時：</color>獲得白虎之賜，額外攻擊的觸發幾率提高30%，且會造成<color=#FFDCBD>真實傷害</color>，持續6秒。</size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>근접 공격 시</color> 15% 확률로 추가 타격이 '
#          '발생합니다. <b>・</b><color=#C83E48>분노 100 달성 시</color> 백호의 가호를 받습니다. 추가 '
#          '타격의 발동 확률이 30% 증가하고 <color=#FFDCBD>고정 피해</color>가 적용됩니다. 효과는 6초간 '
#          '지속됩니다.</size>',
#   'Name': 'PN_DESC_2_3_0'},
#  {'CHT': '<size=17><b>・</b>近戰攻擊+20%\n'
#          '<b>・</b><color=#C83E48>近戰攻擊時：</color>有5%的幾率使你的攻擊速度提高15%，持續2秒。</size>',
#   'KOR': '<size=17><b>・</b>근접 공격 피해 +20% <b>・</b><color=#C83E48>근접 공격 '
#          '시</color> 5% 확률로 공격 속도가 2초간 15% 증가합니다.</size>',
#   'Name': 'PN_DESC_2_0_1'},
#  {'CHT': '<size=17><b>・</b>攻擊速度+14%\n'
#          '<b>・</b>移動速度+10%\n'
#          '<b>・</b><color=#C83E48>近戰攻擊時：</color>使你的移動速度提高3%，持續3秒，最多疊加5層。</size>',
#   'KOR': '<size=17><b>・</b>공격 속도 +14% 이동 속도 +10% <b>・</b><color=#C83E48>근접 공격 '
#          '시</color> 이동 속도가 3초간 3% 증가합니다. 이 효과는 최대 5회 중첩됩니다.</size>',
#   'Name': 'PN_DESC_2_1_1'},
#  {'CHT': '<size=17><b>・</b>近戰攻擊+10%\n'
#          '<b>・</b>防禦+8%\n'
#          '<b>・</b>每當你連續移動超過4秒，使你的下一次近戰傷害提高60%。</size>',
#   'KOR': '<size=17><b>・</b>근접 공격 피해 +10% <b>・</b>방어력 +8% <b>・</b>이동 상태를 4초간 '
#          '유지하면 다음 근접 피해가 60% 증가합니다.</size>',
#   'Name': 'PN_DESC_2_2_1'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>近戰攻擊時：</color>有25%的幾率追加一次額外攻擊。\n'
#          '<b>・</b><color=#C83E48>怒氣達到100時：</color>獲得白虎之賜，額外攻擊的觸發幾率提高40%，且會造成<color=#FFDCBD>真實傷害</color>，持續6秒。</size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>근접 공격 시</color> 25% 확률로 추가 타격이 '
#          '발생합니다. <b>・</b><color=#C83E48>분노 100 달성 시</color> 백호의 가호를 받습니다. 추가 '
#          '타격의 발동 확률이 40% 증가하고 <color=#FFDCBD>고정 피해</color>가 적용됩니다. 효과는 6초간 '
#          '지속됩니다.</size>',
#   'Name': 'PN_DESC_2_3_1'},
#  {'CHT': '<size=17><b>・</b>近戰攻擊+30%\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>近戰攻擊時：</color>有5%的幾率使你的攻擊速度提高15%，持續2秒。\n'
#          '<b>・</b><color=#C83E48>造成近戰傷害時：</color>使你的近戰攻擊提高3%，持續2秒，最大疊加5層。</color></size>',
#   'KOR': '<size=17><b>・</b>근접 공격 피해 +30% '
#          '<color=#FB8204><b>・</b><color=#C83E48>근접 공격 시</color> 5% 확률로 공격 속도가 '
#          '2초간 15% 증가합니다. <b>・</b><color=#C83E48>적에게 근접 공격을 가하면</color> 근접 공격 '
#          '피해가 2초간 3% 증가합니다. 이 효과는 최대 5회 중첩됩니다.</color></size>',
#   'Name': 'PN_DESC_2_0_2'},
#  {'CHT': '<size=17><b>・</b>攻擊速度+21%\n'
#          '<b>・</b>移動速度+15%\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>近戰攻擊時：</color>使你的攻擊速度和移動速度提高3%，持續3秒，最多疊加5層。</color></size>',
#   'KOR': '<size=17><b>・</b>공격 속도 +21% 이동 속도 +15% '
#          '<color=#FB8204><b>・</b><color=#C83E48>근접 공격 시</color> 이동 속도가 3초간 3% '
#          '증가합니다. 이 효과는 최대 5회 중첩됩니다.</color></size>',
#   'Name': 'PN_DESC_2_1_2'},
#  {'CHT': '<size=17><b>・</b>近戰攻擊+15%\n'
#          '<b>・</b>防禦+12%\n'
#          '<color=#FB8204><b>・</b>每當你連續移動超過4秒，使你的下一次近戰傷害提高120%。</color></size>',
#   'KOR': '<size=17><b>・</b>근접 공격 피해 +15% <b>・</b>방어력 +12% '
#          '<color=#FB8204><b>・</b>이동 상태를 4초간 유지하면 다음 근접 피해가 120% '
#          '증가합니다.</color></size>',
#   'Name': 'PN_DESC_2_2_2'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>近戰攻擊時：</color>有35%的幾率追加一次額外攻擊。\xa0\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>怒氣達到100時：</color>獲得白虎之賜，額外攻擊的觸發幾率提高65%，且會造成<color=#FFDCBD>真實傷害</color>，持續8秒。</color></size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>근접 공격 시</color> 35% 확률로 추가 타격이 '
#          '발생합니다. <color=#FB8204><b>・</b><color=#C83E48>분노 100 달성 시</color> 백호의 '
#          '가호를 받습니다. 추가 타격의 발동 확률이 65% 증가하고 <color=#FFDCBD>고정 피해</color>가 '
#          '적용됩니다. 효과는 8초간 지속됩니다.</color></size>',
#   'Name': 'PN_DESC_2_3_2'},
#  {'CHT': '<size=17><b>・</b>飛劍攻擊+10%</size>',
#   'KOR': '<size=17><b>・</b>비검 피해 +10%</size>',
#   'Name': 'PN_DESC_3_0_0'},
#  {'CHT': '<size=17><b>・</b>每當你移動超過3秒，使你的下一次飛劍傷害提高50%。</size>',
#   'KOR': '<size=17><b>・</b>이동 상태를 3초간 유지하면 다음 비검 피해가 50% 증가합니다.</size>',
#   'Name': 'PN_DESC_3_1_0'},
#  {'CHT': '<size=17><b>・</b>飛劍攻擊+5%\n<b>・</b>防禦+4%</size>',
#   'KOR': '<size=17><b>・</b>비검 피해 +5% <b>・</b>방어력 +4%</size>',
#   'Name': 'PN_DESC_3_2_0'},
#  {'CHT': '<size=17><b>・</b>每8秒使你的下一次飛劍傷害附加一道閃電造成{atk*1.4}點<color=#FFDCBD>真實傷害</color>。\xa0\n'
#          '<b>・</b><color=#C83E48>怒氣達到100時：</color>獲得青龍之賜，閃電充能時間變為2秒，持續10秒。</size>',
#   'KOR': '<size=17><b>・</b>8초마다 다음 비검 공격에 벼락 한 줄기가 따라붙어 {atk*1.4} '
#          '<color=#FFDCBD>고정 피해</color>를 줍니다.\xa0 <b>・</b><color=#C83E48>분노 100 '
#          '달성 시</color> 청룡의 가호를 받습니다. 10초간 벼락의 충전 시간이 2초로 변경됩니다.</size>',
#   'Name': 'PN_DESC_3_3_0'},
#  {'CHT': '<size=17><b>・</b>飛劍攻擊+20%\n'
#          '<b>・</b><color=#C83E48>造成飛劍傷害時：</color>有5%的幾率為你恢復3%的生命值。</size>',
#   'KOR': '<size=17><b>・</b>비검 피해 +20% <b>・</b><color=#C83E48>비검으로 피해를 '
#          '입히면</color> 5% 확률로 생명력을 3% 회복합니다.</size>',
#   'Name': 'PN_DESC_3_0_1'},
#  {'CHT': '<size=17><b>・</b>每當你移動超過3秒，使你的下一次飛劍傷害提高100%。</size>',
#   'KOR': '<size=17><b>・</b>이동 상태를 3초간 유지하면 다음 비검 피해가 100% 증가합니다.</size>',
#   'Name': 'PN_DESC_3_1_1'},
#  {'CHT': '<size=17><b>・</b>飛劍攻擊+10%\n'
#          '<b>・</b>防禦+8%\n'
#          '<b>・</b>收劍冷卻時間減少15%。</size>',
#   'KOR': '<size=17><b>・</b>비검 피해 +10% <b>・</b>방어력 +8% <b>・</b>검 회수 재사용 대기시간 '
#          '-15%</size>',
#   'Name': 'PN_DESC_3_2_1'},
#  {'CHT': '<size=17><b>・</b>每8秒使你的下一次飛劍傷害附加一道閃電造成{atk*2.1}點<color=#FFDCBD>真實傷害</color>。\xa0\n'
#          '<b>・</b><color=#C83E48>怒氣達到100時：</color>獲得青龍之賜，飛劍傷害提高40%，閃電充能時間變為2秒，持續10秒。</size>',
#   'KOR': '<size=17><b>・</b>8초마다 다음 비검 피해에 벼락 한 줄기가 따라붙어 {atk*2.1} '
#          '<color=#FFDCBD>고정 피해</color>를 줍니다.\xa0 <b>・</b><color=#C83E48>분노 100 '
#          '달성 시</color>: 청룡의 가호를 받습니다. 비검 피해가 40% 증가하고 10초간 벼락의 충전 시간이 1초로 '
#          '변경됩니다.</size>',
#   'Name': 'PN_DESC_3_3_1'},
#  {'CHT': '<size=17><b>・</b>飛劍攻擊+30%\n'
#          '<b>・</b><color=#C83E48>造成飛劍傷害時：</color>有5%的幾率為你恢復3%的生命值。\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>造成飛劍傷害時：</color>有10%的幾率追加30%飛劍攻擊力的無視防禦傷害。</color></size>',
#   'KOR': '<size=17><b>・</b>비검 피해 +30% <b>・</b><color=#C83E48>비검으로 피해를 '
#          '입히면</color> 5% 확률로 생명력을 3% 회복합니다. '
#          '<color=#FB8204><b>・</b><color=#C83E48>적에게 비검으로 피해를 입히면</color> 10% '
#          '확률로 비검 피해의 30%에 해당하는 고정 피해가 추가로 발생합니다.</color></size>',
#   'Name': 'PN_DESC_3_0_2'},
#  {'CHT': '<size=17><b>・</b>每當你移動超過3秒，使你的下一次飛劍傷害提高150%。\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>造成飛劍傷害時：</color>有5%的幾率追加30%飛劍攻擊力的無視防禦傷害。</color></size>',
#   'KOR': '<size=17><b>・</b>이동 상태를 3초간 유지하면 다음 비검 피해가 150% 증가합니다. '
#          '<color=#FB8204><b>・</b><color=#C83E48>비검으로 피해를 입히면</color> 5% 확률로 비검 '
#          '피해의 30%에 해당하는 고정 피해가 추가로 발생합니다.</color></size>',
#   'Name': 'PN_DESC_3_1_2'},
#  {'CHT': '<size=17><b>・</b>飛劍攻擊+15%\n'
#          '<b>・</b>防禦+12%\n'
#          '<color=#FB8204><b>・</b>收劍冷卻時間減少25%。</color></size>',
#   'KOR': '<size=17><b>・</b>비검 피해 +15% <b>・</b>방어력 +12% '
#          '<color=#FB8204><b>・</b>검 회수 재사용 대기시간 -25%</color></size>',
#   'Name': 'PN_DESC_3_2_2'},
#  {'CHT': '<size=17><b>・</b>每8秒使你的下一次飛劍傷害附加一道閃電造成{atk*2.8}點<color=#FFDCBD>真實傷害</color>。\n'
#          '<color=#FB8204><b>・</b><color=#C83E48>怒氣達到100時：</color>獲得青龍之賜，飛劍傷害提高80%，閃電充能時間變為1秒，持續10秒。</color></size>',
#   'KOR': '<size=17><b>・</b>8초마다 다음 비검 피해에 벼락 한 줄기가 따라붙어 {atk*2.8} '
#          '<color=#FFDCBD>고정 피해</color>를 줍니다.\xa0 '
#          '<color=#FB8204><b>・</b><color=#C83E48>분노 100 달성 시</color> 청룡의 가호를 '
#          '받습니다. 비검 피해가 80% 증가하고 10초간 벼락의 충전 시간이 1초로 변경됩니다.</color></size>',
#   'Name': 'PN_DESC_3_3_2'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>造成傷害時：</color>額外造成相當於你攻擊力3%的<color=#FFDCBD>真實傷害</color>。</size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>적에게 피해를 입하면</color> 공격력의 3%에 해당하는 '
#          '<color=#FFDCBD>고정 피해</color>가 추가로 발생합니다.</size>',
#   'Name': 'PN_DESC_4_0_0'},
#  {'CHT': '<size=17><b>・</b>每擁有1層聖物精煉效果，移動速度提高0.5%。</size>\n'
#          '（當前移動速度提高：{refineCount*0.5}%）',
#   'KOR': '<size=17><b>・</b>소지한 성물의 단련 효과 중첩이 오를 때마다 이동 속도가 0.5% 증가합니다.</size> '
#          '(현재 이동 속도 보너스: {refineCount*0.5}%)',
#   'Name': 'PN_DESC_4_1_0'},
#  {'CHT': '<size=17><b>・</b>你每擁有1層聖物精煉效果，使你的防禦提高0.5%。</size>\n'
#          '（當前額外防禦提高：{refineCount*0.5}%）',
#   'KOR': '<size=17><b>・</b>소지한 성물의 단련 효과 중첩이 오를 때마다 방어력이 0.5% 증가합니다.</size> '
#          '(현재 방어력 보너스: {refineCount*0.5}%)',
#   'Name': 'PN_DESC_4_2_0'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>造成傷害時：</color>有10%的幾率發射朱雀之炎對敵人造成<color=#E35428>{atk*0.4}</color>點<color=#E35428>火焰傷害</color>。每層聖物精煉效果會有額外3%的幾率追加一次發射。</size>（追加發射幾率：{refineCount*3}%）\n'
#          '<size=17><b>・</b><color=#C83E48>怒氣達到100時：</color>獲得朱雀之賜，使你的所有傷害提高30%，每秒對周圍的敵人造成<color=#E35428>{atk*0.7}</color>點<color=#E35428>火焰傷害</color>，持續5秒。</size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>적에게 피해를 입히면</color> 10% 확률로 주작지염을 '
#          '발사하여 적에게 <color=#E35428>{atk*0.4}</color>만큼 '
#          '<color=#E35428>화염피해</color>를 줍니다. 성물 단련 효과의 중첩 수만큼 주작지염이 추가로 발사될 확률이 '
#          '3%씩 증가합니다.</size>(추가 발사 확률: {refineCount*3}%). '
#          '<size=17><b>・</b><color=#C83E48>분노 100 달성 시</color> 주작의 가호를 받습니다. '
#          '가하는 모든 피해가 30% 증가하고 5초간 1초마다 주변 적들에게 '
#          '<color=#E35428>{atk*0.7}</color>만큼 <color=#E35428>화염 피해</color>를 '
#          '줍니다.</size>',
#   'Name': 'PN_DESC_4_3_0'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>造成傷害時：</color>額外造成相當於你攻擊力3%的<color=#FFDCBD>真實傷害</color>。\n'
#          '<b>・</b>你每擁有1層聖物精煉效果會使該技能的額外傷害提高1%。</size>\n'
#          '(當前額外傷害：{refineCount*1}%)',
#   'KOR': '<size=17><b>・</b><color=#C83E48>적에게 피해를 입히면</color> 공격력의 3%에 해당하는 '
#          '<color=#FFDCBD>고정 피해</color>가 추가로 발생합니다.<b>・</b>소지한 성물의 단련 효과 중첩 수만큼 '
#          '추가 공격의 피해량이 1% 증가합니다.</size> (현재 추가 피해: {refineCount*1}%)',
#   'Name': 'PN_DESC_4_0_1'},
#  {'CHT': '<size=17><b>・</b>每擁有1層聖物精煉效果，移動速度提高0.75%。\n'
#          '<b>・</b>移動速度加成的50%會轉化為攻擊速度提高。</size>\n'
#          '（當前移動速度提高：{refineCount*0.75}%\xa0 當前額外攻速：{refineCount*0.375}%)',
#   'KOR': '<size=17><b>・</b>소지한 성물의 단련 효과 중첩 수만큼 이동 속도가 0.75% 증가합니다. '
#          '<b>・</b>추가된 이동 속도의 50%가 공격 속도로 전환됩니다.</size> (현재 추가된 이동 속도: '
#          '{refineCount*0.75}%\xa0 현재 추가된 공격 속도: {refineCount*0.375}%)',
#   'Name': 'PN_DESC_4_1_1'},
#  {'CHT': '<size=17><b>・</b>你每擁有1層聖物精煉效果，使你的防禦提高0.75%。\n'
#          '<b>・</b>當你生命低於20%時，防禦加成提高翻倍。</size>\n'
#          '（當前額外防禦提高：{refineCount*0.75}%)',
#   'KOR': '<size=17><b>・</b>소지한 성물의 단련 효과가 중첩 수만큼 방어력이 0.75% 증가합니다. '
#          '<b>・</b>생명력이 20% 미만일 때 방어력 추가 수치가 2배로 적용됩니다.</size> (현재 추가된 방어력: '
#          '{refineCount*0.75}%)',
#   'Name': 'PN_DESC_4_2_1'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>造成傷害時：</color>有15%的幾率發射朱雀之炎對敵人造成<color=#E35428>{atk*0.5}</color>點<color=#E35428>火焰傷害</color>。每層聖物精煉效果會有額外4%的幾率追加一次發射。</size>（追加發射幾率：{refineCount*4}%）\n'
#          '<size=17><b>・</b><color=#C83E48>怒氣達到100時：</color>獲得朱雀之賜，使你的所有傷害提高45%，每秒對周圍的敵人造成<color=#E35428>{atk*0.9}</color>點<color=#E35428>火焰傷害</color>，持續5秒。</size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>적에게 피해를 입히면</color> 15% 확률로 주작지염을 '
#          '발사하여 적에게 <color=#E35428>{atk*0.5}</color> '
#          '<color=#E35428>화염피해를</color> 줍니다. 성물의 단련 효과 중첩 수만큼 주작지염이 추가로 발사될 확률이 '
#          '4% 증가합니다.</size>(추가 발사 확률: {refineCount*4}%). '
#          '<size=17><b>・</b><color=#C83E48>분노 100 달성 시</color> 주작의 가호를 받습니다. '
#          '가하는 모든 피해가 45% 증가하고 5초간 1초마다 주변의 적들에게 '
#          '<color=#E35428>{atk*0.9}</color> <color=#E35428>화염 피해</color>를 '
#          '줍니다.</size>',
#   'Name': 'PN_DESC_4_3_1'},
#  {'CHT': '<size=17><color=#FB8204><b>・</b><color=#C83E48>造成傷害時：</color>額外造成相當於你攻擊力5%的<color=#FFDCBD>真實傷害</color>。\n'
#          '<b>・</b>你每擁有1層聖物精煉效果會使該技能的額外傷害提高1.5%。</color></size>\n'
#          '(當前額外傷害：{refineCount*1.5}%)',
#   'KOR': '<size=17><color=#FB8204><b>・</b><color=#C83E48>적에게 피해를 입히면</color> '
#          '공격력의 5%에 해당하는 <color=#FFDCBD>고정 피해</color>가 추가로 발생합니다.<b>・</b>소지한 '
#          '성물의 단련 효과 중첩 수만큼 추가 공격의 피해량이 1.5% 증가합니다.</color></size> (현재 추가 피해: '
#          '{refineCount*1.5}%)',
#   'Name': 'PN_DESC_4_0_2'},
#  {'CHT': '<size=17><b>・</b>每擁有1層聖物精煉效果，移動速度提高1%。\n'
#          '<b>・</b>移動速度加成的50%會轉化為攻擊速度提高。\n'
#          '<color=#FB8204><b>・</b>移動速度加成的50%會轉化為所有傷害提高。</color></size>\n'
#          '（當前移動速度提高：{refineCount*1}%\xa0 當前額外傷害和攻速：{refineCount*0.5}%)',
#   'KOR': '<size=17><b>・</b>소지한 성물의 단련 효과 중첩 수만큼 이동 속도가 1% 증가합니다. <b>・</b>추가된 '
#          '이동 속도의 50%가 공격 속도로 전환됩니다. <color=#FB8204><b>・</b>추가된 이동 속도의 50%가 추가 '
#          '피해로 전환됩니다.</color></size> (현재 추가된 이동 속도: {refineCount*1}%\xa0 현재 추가된 '
#          '피해 및 공격 속도: {refineCount*0.5}%)',
#   'Name': 'PN_DESC_4_1_2'},
#  {'CHT': '<size=17><b>・</b>你每擁有1層聖物精煉效果，使你的防禦提高1%。\n'
#          '<b>・</b>當你生命低於20%時，防禦加成提高翻倍。</size>\n'
#          '（當前額外防禦提高：{refineCount*1}%)\n'
#          '<color=#FB8204><b>・</b>使你獲得傳說聖物的幾率提高5%。</color>',
#   'KOR': '<size=17><b>・</b>소지한 성물의 단련 효과 중첩 수만큼 방어력이 1% 증가합니다. <b>・</b>생명력이 '
#          '20% 미만일 때 방어력 추가 수치가 2배로 적용됩니다.</size> (현재 추가된 방어력: '
#          '{refineCount*1}%) <color=#FB8204><b>・</b>전설 등급 성물을 획득할 확률이 5% '
#          '증가합니다.</color>',
#   'Name': 'PN_DESC_4_2_2'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>造成傷害時：</color>有20%的幾率發射朱雀之炎對敵人造成<color=#E35428>{atk*0.7}</color>點<color=#E35428>火焰傷害</color>。每層聖物精煉效果會有額外5%的幾率追加一次發射。</size>（追加發射幾率：{refineCount*5}%）\n'
#          '<size=17><color=#FB8204><b>・</b><color=#C83E48>怒氣達到100時：</color>獲得朱雀之賜，使你的所有傷害提高60%，每秒對周圍的敵人造成<color=#E35428>{atk*1.2}</color>點<color=#E35428>火焰傷害</color>並大幅降低其防禦，持續5秒。</color></size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>적에게 피해를 입히면</color> 20% 확률로 주작지염을 '
#          '발사하여 적에게 <color=#E35428>{atk*0.7}</color> '
#          '<color=#E35428>화염피해를</color> 줍니다. 성물의 단련 효과 중첩 수만큼 주작지염이 추가로 발사될 확률이 '
#          '5% 증가합니다.</size>(추가 발사 확률: {refineCount*5}%). '
#          '<size=17><color=#FB8204><b>・</b><color=#C83E48>분노 100 달성 시</color> '
#          '주작의 가호를 받습니다. 가하는 모든 피해가 60% 증가하고 5초간 1초마다 주변의 적들에게 '
#          '<color=#E35428>{atk*1.2}</color> <color=#E35428>화염 피해</color>를 주고 '
#          '방어력을 대폭 감소시킵니다.</color></size>',
#   'Name': 'PN_DESC_4_3_2'},
#  {'CHT': '<size=17><b>・</b><color=#C83E48>造成傷害時：</color>有15%幾率對敵人造成<color=#C549EC>[中毒]</color>效果。</size>',
#   'KOR': '<size=17><b>・</b><color=#C83E48>적에게 피해를 입히면</color> 15% 확률로 적에게 '
#          '<color=#C549EC>[중독]</color> 상태를 부여합니다.</size>',
#   'Name': 'PN_DESC_5_0_0'},
#  {'CHT': '<size=17><b>・</b>移動速度+5%\n'
#          '<b>・</b><color=#70DE9E>受擊時：</color>有15%的幾率使敵人<color=#C549EC>[中毒]</color>。</size>',
#   'KOR': '<size=17><b>・</b>이동 속도 +5% <b>・</b><color=#70DE9E>피격 시</color> 15% '
#          '확률로 적에게 <color=#C549EC>[중독]</color> 상태를 부여합니다.</size>',
#   'Name': 'PN_DESC_5_1_0'},
#  {'CHT': '<size=17><b>・</b>使你造成的<color=#C549EC>[中毒]</color>效果和<color=#8B008B>[劇毒]</color>效果能夠疊加2次。</size>',
#   'KOR': '<size=17><b>・</b>부여하는 <color=#C549EC>[중독]</color>과 '
# ...
#   'Name': 'UI_DLC2_Talent_Tips_8'},
#  {'CHT': '尚有天賦點數<color=#CB484B>未使用</color>，請前往<color=#CB484B>森羅萬象天賦盤</color>。',
#   'KOR': '<color=#CB484B>미사용</color> 재능 점수가 있습니다, <color=#CB484B>삼라만상의 심장의 '
#          '나침반</color>으로 가십시오',
#   'Name': 'UI_DLC2_Talent_Tips_9'},
#  {'CHT': '解鎖故事碎片<color=#CB484B>“英雄讚歌”</color>後，可獲得額外點數。',
#   'KOR': '이야기 <color=#CB484B>“영웅찬가”</color> 해금 후, 추가 점수를 얻을 수 있습니다.',
#   'Name': 'UI_DLC2_Talent_Tips_10'},
#  {'CHT': '等級\n(最高等級 : <size=17>43</size>)',
#   'KOR': '등급\n(최고등급 : <size=17>43</size>)',
#   'Name': 'UI_DLC2_Talent_Level'},
#  {'CHT': '剩餘點數', 'KOR': '남은 점수', 'Name': 'UI_DLC2_Talent_TalentPoint'},
#  {'CHT': '<color=#CB484B>絕對瘋狂</color>',
#   'KOR': '<color=#CB484B>절대적인 광기</color>',
#   'Name': 'Trail_Name_11'},
#  {'CHT': '<color=#CB484B>命定死亡</color>',
#   'KOR': '<color=#CB484B>정해진 사망</color>',
#   'Name': 'Trail_Name_12'},
#  {'CHT': '<color=#CB484B>混沌現實</color>',
#   'KOR': '<color=#CB484B>혼돈한 현실</color>',
#   'Name': 'Trail_Name_13'},
#  {'CHT': '<color=#CB484B>致命知識</color>',
#   'KOR': '<color=#CB484B>치명적인 지식</color>',
#   'Name': 'Trail_Name_14'},
#  {'CHT': '<color=#CB484B>豬還再來</color>',
#   'KOR': '<color=#CB484B>저환재래</color>',
#   'Name': 'Trail_Name_15'},
#  {'CHT': '<color=#CB484B>身先士卒</color>',
#   'KOR': '<color=#CB484B>신선사졸</color>',
#   'Name': 'Trail_Name_16'},
#  {'CHT': '<color=#CB484B>深海崛起</color>',
#   'KOR': '<color=#CB484B>심해굴기</color>',
#   'Name': 'Trail_Name_17'},
#  {'CHT': '<color=#CB484B>无坚不摧</color>',
#   'KOR': '<color=#CB484B>무견불쇄</color>',
#   'Name': 'Trail_Name_18'},
#  {'CHT': '<color=#CB484B>惡寒地脈</color>',
#   'KOR': '<color=#CB484B>악한지맥</color>',
#   'Name': 'Trail_Name_19'},
#  {'CHT': '<color=#CB484B>血海深仇</color>',
#   'KOR': '<color=#CB484B>혈해심구</color>',
#   'Name': 'Trail_Name_20'},
#  {'CHT': '<color=#CB484B>靈魂重擔</color>',
#   'KOR': '<color=#CB484B>영혼중담</color>',
#   'Name': 'Trail_Name_21'},
#  {'CHT': '<color=#CB484B>不滅王者</color>',
#   'KOR': '<color=#CB484B>불멸의 왕자</color>',
#   'Name': 'Trail_Name_22'},
#  {'CHT': '<color=#CB484B>索命鴛鴦</color>',
#   'KOR': '<color=#CB484B>삭명원앙</color>',
#   'Name': 'Trail_Name_23'},
#  {'CHT': '<color=#CB484B>時間缺失</color>',
#   'KOR': '<color=#CB484B>시간손실</color>',
#   'Name': 'Trail_Name_24'},
#  {'CHT': '所有非首領敵人都獲得何羅賜福。',
#   'KOR': '우두머리가 아닌 모든 적이 하라신의 축복을 받습니다.',
#   'Name': 'Trail_Desc_11'},
#  {'CHT': '你無法對首領敵人造成任何傷害，首領敵人造成的所有傷害提高50%，但首領敵人會每秒失去1%的最大生命值。',
#   'KOR': '우두머리에게 어떤 피해도 줄 수 없으며, 우두머리가 주는 모든 피해가 50% 증가하지만 매초 최대 생명력의 1%를 '
#          '잃습니다.',
#   'Name': 'Trail_Desc_12'},
#  {'CHT': '每次抵達中轉站時，隨機將你攜帶的一個聖物變成另一個隨機聖物。',
#   'KOR': '중계지에 도착할 때마다 소지한 성물 중 하나가 무작위로 다른 성물로 변합니다.',
#   'Name': 'Trail_Desc_13'},
#  {'CHT': '每學習一本秘笈，你受到的所有傷害提高25%。每當你學習秘笈時，有20%的幾率再獲得1本秘笈',
#   'KOR': '비급을 하나 익힐 때마다 받는 모든 피해가 25% 증가합니다. 비급을 익힐 때 20% 확률로 추가 비급을 획득합니다.',
#   'Name': 'Trail_Desc_14'},
#  {'CHT': '每張地圖都有15%的幾率誕生一只變異雙頭豬，該雙頭豬死亡時有概率掉落1個隨機品質的任意殘響。',
#   'KOR': '각 지도마다 15% 확률로 변이 쌍두저가 출현합니다. 쌍두저가 죽을 때 무작위 품질의 잔향을 드롭할 수 있습니다.',
#   'Name': 'Trail_Desc_15'},
#  {'CHT': '受到何羅賜福的敵人，造成的傷害提高60%。',
#   'KOR': '하라신의 축복을 받은 적이 주는 피해가 60% 증가합니다.',
#   'Name': 'Trail_Desc_16'},
#  {'CHT': '每張戰鬥地圖額外追加一只必帶詞綴的深潛獵殺者。',
#   'KOR': '모든 전투 지도에 필수 접두사가 붙은 심해 사냥꾼이 추가로 등장합니다.',
#   'Name': 'Trail_Desc_17'},
#  {'CHT': '所有敵人的傷害提高30%，當你受到傷害時，會移除你所有護盾效果。',
#   'KOR': '모든 적의 피해가 30% 증가하며, 피해를 받을 때 모든 방패 효과가 제거됩니다.',
#   'Name': 'Trail_Desc_18'},
#  {'CHT': '你的移動速度降低25%，受到任何傷害時都會使你倒地，當你處於倒地狀態時，每秒受到最大生命值8%的傷害。',
#   'KOR': '이동 속도가 25% 감소하고, 어떤 피해를 받아도 쓰러집니다. 쓰러진 상태에서 매초 최대 생명력의 8%에 해당하는 피해를 '
#          '받습니다.',
#   'Name': 'Trail_Desc_19'},
#  {'CHT': '你受到的所有傷害提高25%，你每擊殺1個敵人使你受到的所有傷害提高0.5%。',
#   'KOR': '받는 모든 피해가 25% 증가하며, 적 하나를 처치할 때마다 받는 피해가 0.5% 증가합니다.',
#   'Name': 'Trail_Desc_20'},
#  {'CHT': '你每擁有100點幽冥之魂，你的移動速度和瞬身距離下降1%，最大下降75%。',
#   'KOR': '유명지혼 100점마다 이동 속도와 질주 거리가 1% 감소하며, 최대 75%까지 감소합니다.',
#   'Name': 'Trail_Desc_21'},
#  {'CHT': '進入首領戰時，首領受到的所有傷害降低100%，該減傷效果會隨著時間變弱，在30秒後完全失效。',
#   'KOR': '우두머리 전투 시작 시 우두머리가 받는 모든 피해가 100% 감소하며, 이 효과는 시간이 지날수록 약해져 30초 후 완전히 '
#          '사라집니다.',
#   'Name': 'Trail_Desc_22'},
#  {'CHT': '擊敗[青逸]後，[青逸]會開始追殺你，[青逸]每次被擊殺，下次復活造成的傷害會提高15%，生命提高50%。',
#   'KOR': '[청일]을 물리친 후, [청일]이 당신을 추적하기 시작합니다. [청일]이 죽을 때마다 다음 부활 시 주는 피해가 15%, '
#          '생명력이 50% 증가합니다.',
#   'Name': 'Trail_Desc_23'},
#  {'CHT': '頻繁的重啟時間使你的意識混沌不堪，當你通過地圖時，你將無法保持身上已有的狀態。',
#   'KOR': '잦은 시간 재시작으로 의식이 혼미해져, 지도를 통과할 때 기존의 상태 효과를 유지할 수 없습니다.',
#   'Name': 'Trail_Desc_24'},
#  {'CHT': '獎勵:\n'
#          '紅魂掉落提高200%\n'
#          '擊敗何羅神後會額外掉落5個<color=#CB484B>雙詞條</color>的<color=#CB484B>秘寶品質的終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 200% 증가\n'
#          '하라신을 처치하면 <color=#CB484B>이중 옵션</color>이 있는 <color=#CB484B>보물 등급 궁극의 '
#          '잔향</color> 5개를 추가로 획득합니다.',
#   'Name': 'Trial_Award_11'},
#  {'CHT': '獎勵:\n'
#          '紅魂掉落提高100%\n'
#          '擊敗關底首領後會額外掉落1個<color=#CB484B>雙詞條</color>的<color=#CB484B>秘寶品質的終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '스테이지 우두머리를 처치하면 <color=#CB484B>이중 옵션</color>이 있는 <color=#CB484B>보물 '
#          '등급 궁극의 잔향</color> 1개를 추가로 획득합니다.',
#   'Name': 'Trial_Award_12'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗關底首領後會額外掉落1個<color=#E57E00>傳說或以上品質的終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '스테이지 우두머리를 처치하면 <color=#E57E00>전설 등급 이상의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_13'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗關底首領後會額外掉落1個<color=#AB28FF>隨機品質終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '스테이지 우두머리를 처치하면 <color=#AB28FF>무작위 등급의 궁극의 잔향</color> 1개를 추가로 획득합니다.',
#   'Name': 'Trial_Award_14'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗關底首領後會額外掉落1個<color=#E57E00>傳說或以上品質的終極殘響</color>。',
#   'KOR': '보상:\n붉은 혼 획득량 100% 증가\n시간의 잔광 획득량 100% 증가',
#   'Name': 'Trial_Award_15'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n時間餘暉掉落量提高100%',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '시간의 잔광 획득량 100% 증가\n'
#          '스테이지 우두머리를 처치하면 <color=#E57E00>전설 등급 이상의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_16'},
#  {'CHT': '獎勵:\n'
#          '紅魂掉落提高100%\n'
#          '時間餘暉掉落量提高100%\n'
#          '擊敗關底首領後會額外掉落1個<color=#E57E00>傳說或以上品質的終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '모든 우두머리를 처치할 때마다 <color=#AB28FF>무작위 등급의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_17'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗每個首領後會額外掉落1個<color=#AB28FF>隨機品質終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '모든 우두머리를 처치할 때마다 <color=#AB28FF>무작위 등급의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_18'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗每個首領後會額外掉落1個<color=#AB28FF>隨機品質終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '모든 우두머리를 처치할 때마다 <color=#AB28FF>무작위 등급의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_19'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗每個首領後會額外掉落1個<color=#AB28FF>隨機品質終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '모든 우두머리를 처치할 때마다 <color=#AB28FF>무작위 등급의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_20'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗每個首領後會額外掉落1個<color=#AB28FF>隨機品質終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '모든 우두머리를 처치할 때마다 <color=#AB28FF>무작위 등급의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_21'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗關底首領後會額外掉落1個<color=#E57E00>傳說或以上品質的終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '스테이지 우두머리를 처치하면 <color=#E57E00>전설 등급 이상의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_22'},
#  {'CHT': '獎勵:\n'
#          '紅魂掉落提高100%\n'
#          '擊敗關底首領後會額外掉落1個<color=#CB484B>雙詞條</color>的<color=#CB484B>秘寶品質的終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '스테이지 우두머리를 처치하면 <color=#CB484B>추가 효과</color>가 있는 <color=#CB484B>보물 '
#          '등급 궁극의 잔향</color> 1개를 추가로 획득합니다.',
#   'Name': 'Trial_Award_23'},
#  {'CHT': '獎勵:\n紅魂掉落提高100%\n擊敗關底首領後會額外掉落1個<color=#E57E00>傳說或以上品質的終極殘響</color>。',
#   'KOR': '보상:\n'
#          '붉은 혼 획득량 100% 증가\n'
#          '스테이지 우두머리를 처치하면 <color=#E57E00>전설 등급 이상의 궁극의 잔향</color> 1개를 추가로 '
#          '획득합니다.',
#   'Name': 'Trial_Award_24'},
#  {'CHT': '直到下次抵達中轉站，攻擊力提高100%。',
#   'KOR': '다음 경유지에 도달할 때까지 공격력이 100% 증가합니다.',
#   'Name': 'COP_Desc_19'},
#  {'CHT': '直到下次抵達中轉站，獲取藍魂量提高100%',
#   'KOR': '다음 경유지에 도달할 때까지 푸른 혼 획득량이 100% 증가합니다.',
#   'Name': 'COP_Desc_20'},
#  {'CHT': '直到下次抵達中轉站，你的怒氣獲取提升30%。',
#   'KOR': '다음 경유지에 도달할 때까지 분노 획득량이 30% 증가합니다.',
#   'Name': 'COP_Desc_21'},
#  {'CHT': '直到下次抵達中轉站，僅一次當你受到致命傷害時，抵擋致命傷並回復60%最大生命值。',
#   'KOR': '다음 경유지에 도달할 때까지 치명적인 피해를 1회 막고 최대 생명력의 60%를 회복합니다.',
#   'Name': 'COP_Desc_22'},
#  {'CHT': '直到下次抵達中轉站，擁有詞綴的敵人對你造成的傷害減少30%',
#   'KOR': '다음 경유지에 도달할 때까지 접두사가 있는 적이 가하는 피해가 30% 감소합니다.',
#   'Name': 'COP_Desc_23'},
#  {'CHT': '直到下次抵達中轉站，每過45秒生成一個抵擋3次傷害的的護盾',
#   'KOR': '다음 경유지에 도달할 때까지 45초마다 피해를 3회 막아주는 방패가 생성됩니다.',
#   'Name': 'COP_Desc_24'},
#  {'CHT': '直到下次抵達中轉站，屬性傷害提高100%',
#   'KOR': '다음 경유지에 도달할 때까지 속성 피해가 100% 증가합니다.',
#   'Name': 'COP_Desc_25'},
#  {'CHT': '直到下次抵達中轉站，額外造成50%真實傷害',
#   'KOR': '다음 경유지에 도달할 때까지 50%의 고정 피해가 추가됩니다.',
#   'Name': 'COP_Desc_26'},
#  {'CHT': '直到下次抵達中轉站，你受到的所有傷害降低30%，每次起身後擁有2秒霸體。',
#   'KOR': '다음 경유지에 도달할 때까지 받는 모든 피해가 30% 감소하며, 일어설 때 2초간 경직되지 않습니다.',
#   'Name': 'COP_Desc_27'},
#  {'CHT': '直到下次抵達中轉站，非首領敵人攻擊力提高30%。\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，獲得1本<color=#E57E00>金色秘笈</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 공격력이 30% 증가합니다. <color=#89E7A0>보상: 다음 '
#          '경유지 도착 시 <color=#E57E00>금색 비급</color> 1권을 획득합니다.</color>',
#   'Name': 'COP_Desc_28'},
#  {'CHT': '直到下次抵達中轉站，非首領敵人數量*2。\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，獲得2本<color=#E57E00>金色秘笈</color>。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 수가 2배가 됩니다. <color=#89E7A0>보상: 다음 경유지 도착 '
#          '시 <color=#E57E00>금색 비급</color> 2권을 획득합니다.</color>',
#   'Name': 'COP_Desc_29'},
#  {'CHT': '直到下次抵達中轉站，所有敵人傷害提高20%。\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局藍魂獲取量提高 200%。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 모든 적의 피해가 20% 증가합니다. <color=#89E7A0>보상: 다음 경유지 도착 시 '
#          '이번 게임 동안 푸른 혼 획득량이 200% 증가합니다.</color>',
#   'Name': 'COP_Desc_30'},
#  {'CHT': '直到下次抵達中轉站，敵人血量與攻擊力提升20%，\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，獎勵大量時間餘暉。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 적의 생명력과 공격력이 20% 증가합니다. <color=#89E7A0>보상: 다음 경유지 도착 '
#          '시 시간의 잔광을 대량으로 획득합니다.</color>',
#   'Name': 'COP_Desc_31'},
#  {'CHT': '直到下次抵達中轉站，所有敵人攻擊命中時，回復自身5%最大生命值。\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站，獎勵大量時間餘暉。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 모든 적의 공격이 적중할 때마다 자신의 최대 생명력의 5%를 회복합니다. '
#          '<color=#89E7A0>보상: 다음 경유지 도착 시 시간의 잔광을 대량으로 획득합니다.</color>',
#   'Name': 'COP_Desc_32'},
#  {'CHT': '直到下次抵達中轉站，受到的傷害提高30%。\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局攻擊速度提升50%。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 받는 피해가 30% 증가합니다. <color=#89E7A0>보상: 다음 경유지 도착 시 이번 '
#          '게임 동안 공격 속도가 50% 증가합니다.</color>',
#   'Name': 'COP_Desc_33'},
#  {'CHT': '直到下次抵達中轉站，每次倒地時損失當前生命值15%，\n'
#          '<color=#89E7A0>獎勵：下次抵達中轉站時，本局屬性傷害提高50%。</color>',
#   'KOR': '다음 경유지에 도달할 때까지 매번 쓰러질 때마다 현재 생명력의 15%를 잃습니다. <color=#89E7A0>보상: 다음 '
#          '경유지 도착 시 이번 게임 동안 속성 피해가 50% 증가합니다.</color>',
#   'Name': 'COP_Desc_34'},
#  {'CHT': '直到下次抵達中轉站，非首領敵人的生命值提高30%，完成之後收劍冷卻降低25%。',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 생명력이 30% 증가합니다. <color=#89E7A0>보상: 완료 후 '
#          '검 회수의 재사용 대기 시간이 25% 감소합니다.</color>',
#   'Name': 'COP_Desc_35'},
#  {'CHT': '直到下次抵達中轉站，所有敵人的生命值提高30%。完成之後你的每次屬性傷害有15%幾率引發爆炸，追加{atk*3}範圍火焰傷害。（1.5秒內置CD）',
#   'KOR': '다음 경유지에 도달할 때까지 모든 적의 생명력이 30% 증가합니다. <color=#89E7A0>보상: 완료 후 속성 피해를 '
#          '줄 때마다 15% 확률로 폭발이 발생하여 {atk*3}의 범위의 화염 피해를 추가로 줍니다. (내부 재사용 대기 시간: '
#          '1.5초)</color>',
#   'Name': 'COP_Desc_36'},
#  {'CHT': '直到下次抵達中轉站，所有敵人傷害提高30%。完成之後你的所有傷害提高相當於當前生命值百分比的傷害。',
#   'KOR': '다음 경유지에 도달할 때까지 모든 적의 피해가 30% 증가합니다. <color=#89E7A0>보상: 완료 후 모든 공격에 '
#          '현재 생명력 수치만큼의 추가 피해가 발생합니다.</color>',
#   'Name': 'COP_Desc_37'},
#  {'CHT': '直到下次抵達中轉站，非首領敵人的防禦提高30%，完成之後你對異常狀態的敵人造成的傷害提升20%，敵人每額外有一種異常狀態，再提升5%。',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 방어력이 30% 증가합니다. <color=#89E7A0>보상: 완료 후 '
#          '상태이상에 걸린 적에게 가하는 피해가 20% 증가하며, 적이 가진 상태이상 1개당 추가로 5%씩 증가합니다.</color>',
#   'Name': 'COP_Desc_38'},
#  {'CHT': '直到下次抵達中轉站，非首領敵人的生命值提高30%，完成之後每次攻擊有5%幾率為你恢復1%最大生命值。',
#   'KOR': '다음 경유지에 도달할 때까지 우두머리가 아닌 적의 생명력이 30% 증가합니다. <color=#89E7A0>보상: 완료 후 '
#          '공격할 때마다 5% 확률로 최대 생명력의 1%를 회복합니다.</color>',
#   'Name': 'COP_Desc_39'},
#  {'CHT': '直到下次抵達中轉站，所有敵人的防禦提高20%，完成之後每次攻擊追加當前傷害的30%真實傷害。',
#   'KOR': '다음 경유지에 도달할 때까지 모든 적의 방어력이 20% 증가합니다. <color=#89E7A0>보상: 완료 후 모든 공격에 '
#          '현재 피해량의 30%만큼 고정 피해가 추가됩니다.</color>',
#   'Name': 'COP_Desc_40'},
#  {'CHT': '狴犴！~狴犴！~', 'KOR': '비안! ~ 비안!~', 'Name': 'T_Ending1_LINGLONG_1'},
#  {'CHT': '這兒~在這裏~總算找到你啦！~',
#   'KOR': '여기예요~ 마침내 당신을 찾았군요.',
#   'Name': 'T_Ending1_LINGLONG_2'},
#  {'CHT': '這一切都結束了嗎？', 'KOR': '이제 모든게 끝난건가요?', 'Name': 'T_Ending1_LINGLONG_3'},
#  {'CHT': '今天的故事就講到這啦~大家快回去吧！',
#   'KOR': '오늘 이야기는 여기까지예요~ 모두들 돌아가세요!',
#   'Name': 'T_Ending2_LINGLONG_1'},
#  {'CHT': '老師，老師，後來這些英雄們都怎麼樣了？',
#   'KOR': '선생님, 선생님, 그 후에 영웅은 어떻게 되었나요?',
#   'Name': 'T_Ending2_Child_1'},
#  {'CHT': '後來啊，大家都過上了新的生活，',
#   'KOR': '그 후로, 모두가 새로운 삶을 살게 되었죠,',
#   'Name': 'T_Ending2_LINGLONG_2_1'},
#  {'CHT': '有的人變成了富甲一方的大商人，',
#   'KOR': '어떤 이는 온 마을에서 가장 부자인 상인이 되었고,',
#   'Name': 'T_Ending2_LINGLONG_2_2'},
#  {'CHT': '有的人回到了家鄉重建家園，',
#   'KOR': '어떤 이는 고향으로 돌아가 터전을 재건했으며,',
#   'Name': 'T_Ending2_LINGLONG_2_3'},
#  {'CHT': '有的人踏上了新的旅途……',
#   'KOR': '어떤 이는 새로운 여정을 떠났어요...',
#   'Name': 'T_Ending2_LINGLONG_2_4'},
#  {'CHT': '老師，還有一個人呢？', 'KOR': '선생님, 그럼 마지막 사람은요?', 'Name': 'T_Ending2_Child_2'},
#  {'CHT': '他啊……', 'KOR': '그 사람은...', 'Name': 'T_Ending2_LINGLONG_3'},
#  {'CHT': '七千年前，', 'KOR': '칠천년전,', 'Name': 'T_Ending3_SMY_2_1'},
#  {'CHT': '弱小的蛇族接受了無根之神的力量，',
#   'KOR': '약소한 사족들은 뿌리가 없는 신의 힘을 받아들여,',
#   'Name': 'T_Ending3_SMY_2_2'},
#  {'CHT': '成為了它在這片大陸的代行者，',
#   'KOR': '이 대륙의 대행자가 되었다.',
#   'Name': 'T_Ending3_SMY_2_3'},
#  {'CHT': '古老的契約被打破，天平失去了平衡，',
#   'KOR': '오래된 계약이 깨지고, 저울은 기울어져,',
#   'Name': 'T_Ending3_SMY_2_4'},
#  {'CHT': '一切都陷入了混亂之中。', 'KOR': '세상이 혼란에 빠졌다.', 'Name': 'T_Ending3_SMY_2_5'},
#  {'CHT': '在此', 'KOR': '이제 여기에서 나는', 'Name': 'T_Ending3_SMY_2_6'},
#  {'CHT': '我將以新何羅神之名重新立下契約。',
#   'KOR': '새 하라신의 이름으로 새로운 계약을 세운다.',
#   'Name': 'T_Ending3_SMY_2_7'},
#  {'CHT': '無根的子民啊，', 'KOR': '뿌리 없는 백성이여,', 'Name': 'T_Ending3_SMY_2_8'},
#  {'CHT': '請停止這無意義的爭鬥，', 'KOR': '무의미한 싸움을 멈추고,', 'Name': 'T_Ending3_SMY_2_9'},
#  {'CHT': '隨我一同返回大海吧！', 'KOR': '나와 함께 바다로 돌아가자!', 'Name': 'T_Ending3_SMY_2_10'},
#  {'CHT': '從此不再侵犯有根之靈的土地！',
#   'KOR': '뿌리깊은 영혼의 땅을 다시는 침범하지 않겠다는 우리의 다짐을!',
#   'Name': 'T_Ending3_SMY_2_11'},
#  {'CHT': '以天地為證!', 'KOR': '천지를 증거로 삼겠다!', 'Name': 'T_Ending3_SMY_2_12'},
#  {'CHT': '再見了，狴犴哥，', 'KOR': '안녕히, 비안 오라버니,', 'Name': 'T_Ending3_SMY_2_13'},
#  {'CHT': '再見了，大家……', 'KOR': '안녕, 모두들...', 'Name': 'T_Ending3_SMY_2_14'},
#  {'CHT': '抽取殘響精粹(長按快速抽取)',
#   'KOR': '잔향 추출(길게 눌러서 추출)',
#   'Name': 'UI_Roll_Rune_Tip'},
#  {'CHT': '已達上限', 'KOR': '상한에 도달', 'Name': 'UI_DLC2_MAX'},
#  {'CHT': '獲得時自動鎖定秘寶殘響',
#   'KOR': '비보 등급 잔향 획득시 자동으로 잠급니다.',
#   'Name': 'UI_RuneAutoLock'},
#  {'CHT': '開啟/關閉無限森羅模式',
#   'KOR': '열기/닫기 무한 삼라 모드',
#   'Name': 'UI_Toggle_UnlimitedTalent'},
#  {'CHT': '是否開啟無限森羅模式，開啟後將直接擁有86點天賦點數，但以該模式通關不會記錄通關時間和無盡夢魘層數。',
#   'KOR': '무한 삼라 모드 활성화시 즉시 86점의 재능을 얻지만, 통과한 시간이 기록되지 않습니다.',
#   'Name': 'UI_UnlimitedTalent_Confirm'},
#  {'CHT': '無數次的重啟時間，令廢棄的時間線彼此交錯糾纏，並最終影響到了當下的時空，形成了一處混沌中斷點，那些曾經擊敗過你的邪惡，變得更加瘋狂，糾正它亦或是選擇無視，皆在你一念之間.....\n'
#          '\n'
#          '<color=#E57E00>本難度下部分首領戰鬥機制會發生變化。</color>',
#   'KOR': '수없이 많은 시간의 재시작으로 인해 폐기된 시간선들이 서로 얽히고설켜 현재의 시공간에 영향을 미치며, 혼돈의 단절점을 '
#          '형성했습니다. 과거에 당신을 패배시켰던 사악한 존재들이 더욱 광기에 빠졌으니, 이를 바로잡을지 무시할지는 당신의 선택에 '
#          '달려있습니다.....\n'
#          '<color=#E57E00>이 난이도에서는 일부 우두머리의 전투 방식이 변경됩니다.</color>',
#   'Name': 'dlc2_difficult_desc_newDestiny2'},
#  {'CHT': '混沌斷點', 'KOR': '혼돈의 단절점', 'Name': 'dlc2_difficult_6'},
#  {'CHT': '在終業中通關乙亥難度', 'KOR': '종업의 을해 난이도 돌파', 'Name': 'Skin_UnlockTip_3'},
#  {'CHT': '重新游玩無盡夢魘模式',
#   'KOR': '무한의 몽염 모드 다시 플레이',
#   'Name': 'dlc2_EndlessModeEntry'},
#  {'CHT': '·通過本入口進入的無盡夢魘會使用新的層數記錄。\n'
#          '·通過本入口可以使用新的<color=#CB484B>森羅萬象之法天賦</color>挑戰無盡夢魘。\n'
#          '·通過本入口進入的無盡夢魘會遇到新的敵人與首領。',
#   'KOR': '·이 입구를 통해 입장한 무한의 몽염은 새로운 층수 기록을 사용합니다.\n'
#          '·이 입구를 통해 새로운 <color=#CB484B>삼라만상의 법천 특성</color>으로 무한의 몽염에 도전할 수 '
#          '있습니다.\n'
#          '·이 입구를 통해 입장한 무한의 몽염에서는 새로운 적과 우두머리를 만나게 됩니다.',
#   'Name': 'dlc2_EndlessModeDes'}]
